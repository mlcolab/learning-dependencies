# %% [markdown]
# In this and previous notebooks (04_TFIDF_and...) we tried tf-idf, count-vectorizer and SciBERT models to identify named entities or concepts in Mathematics for Machine Learning Textbook.

# %% [markdown]
# ## 1. ScispaCy

# %%
# 1. Create an environment for scispacy
#conda create -n scispacy python=3.9

# 2. Load a model trained on scientific publications
# #! pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_sm-0.5.1.tar.gz
# ! pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_scibert-0.5.1.tar.gz 
! pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.1/en_core_sci_md-0.5.1.tar.gz
# NOTE: scibert doesn't have vectors

# 3. Install spacy
#! pip install spacy


#! pip install pandas
import pandas as pd
import spacy

# %%
data = pd.read_json("../dat/parsed_books/mml.json")
data
# Out:
#                                                                             text
# Analytic Geometry              In Chapter 2, we studied vectors, vector space...
# Continuous Optimization        Since machine learning algorithms are implemen...
# Introduction and Motivation    Machine learning is about designing algorithms...
# Linear Algebra                 When formalizing intuitive concepts, a common ...
# Matrix Decompositions          In Chapters 2 and 3, we studied ways to manipu...
# Probability and Distributions  Probability, loosely speaking, concerns the st...
# Vector Calculus                Many algorithms in machine learning optimize a...

# %%
nlp = spacy.load("en_core_sci_md")
doc=nlp(data.text["Linear Algebra"])
entities_la = doc.ents

# %%
df_entities = pd.DataFrame(columns = ["entity","lemma","start_char","end_char","position in text","embedding"])
for n, entity in enumerate(entities_la):
    df_entities.loc[n,:] = [entity, entity.lemma_.lower(), entity.start_char, entity.end_char, entity.start, entity.vector]
df_entities.head(5)
# Out:
#         entity      lemma start_char end_char position in text  \
# 0  (intuitive)  intuitive         17       26                2
# 1   (concepts)    concept         27       35                3
# 2    (objects)     object         80       87               15
# 3    (symbols)     symbol         89       96               17
# 4      (rules)       rule        111      116               23
#
#                                            embedding
# 0  [-0.271802, 0.0637784, 0.0866259, -0.21584, -0...
# 1  [-0.22106, -0.00857793, -0.0511574, -0.147617,...
# 2  [0.166611, 0.103413, 0.0951793, -0.321065, 0.0...
# 3  [0.218379, 0.264318, 0.223982, -0.680185, 0.36...
# 4  [-0.046738, -0.0100906, 0.0975509, -0.171749, ...

# %%
df_entities.loc[df_entities.lemma == "vector", "embedding"] # shape of embedding is 200
# Out:
# 9       [0.199261, -0.0951729, 0.291055, -0.121187, -0...
# 10      [0.199261, -0.0951729, 0.291055, -0.121187, -0...
# 11      [0.199261, -0.0951729, 0.291055, -0.121187, -0...
# 17      [0.199261, -0.0951729, 0.291055, -0.121187, -0...
# 20      [0.199261, -0.0951729, 0.291055, -0.121187, -0...
#                               ...
# 2417    [0.400419, -0.0290379, 0.289465, -0.116615, -0...
# 2420    [0.199261, -0.0951729, 0.291055, -0.121187, -0...
# 2459    [0.199261, -0.0951729, 0.291055, -0.121187, -0...
# 2463    [0.199261, -0.0951729, 0.291055, -0.121187, -0...
# 2482    [0.400419, -0.0290379, 0.289465, -0.116615, -0...
# Name: embedding, Length: 148, dtype: object

# %%
from collections import defaultdict
freqs = defaultdict(int)
for w in df_entities.lemma:
    freqs[w] += 1

freqs = dict(sorted(freqs.items(), key=lambda item: item[1], reverse = True))
freqs
# Out:
# {'vector': 148,
#  'matrix': 78,
#  'solution': 53,
#  'transformation': 39,
#  'system': 37,
#  'vector space': 35,
#  'linear equation': 32,
#  'column': 31,
#  'subspace': 28,
#  'deﬁne': 27,
#  'mapping': 27,
#  'inverse': 25,
#  'linearly': 24,
#  'coordinate': 24,
#  'basis': 22,
#  'row-echelon': 20,
#  'deﬁnition': 18,
#  'property': 17,
#  'linear combination': 17,
#  'group': 17,
#  'independent': 17,
#  'operation': 16,
#  'space': 16,
#  'variable': 16,
#  'dimension': 16,
#  'reduce': 15,
#  'concept': 14,
#  'multiplication': 14,
#  'linear mapping': 14,
#  'representation': 14,
#  'section': 13,
#  'kernel': 13,
#  'scalar': 12,
#  'geometric vector': 11,
#  'equation': 11,
#  'pivot column': 11,
#  'image': 11,
#  'element': 10,
#  'plane': 10,
#  'pivot': 10,
#  'afﬁne subspace': 10,
#  'matrix multiplication': 9,
#  'general solution': 9,
#  'object': 8,
#  'polynomial': 8,
#  'rn': 8,
#  'row': 8,
#  'gaussian': 8,
#  'vector subspace': 8,
#  'linear mapping \x08': 8,
#  'case': 7,
#  'unique': 7,
#  'elimination': 7,
#  'elementary': 7,
#  'express': 7,
#  'rank': 7,
#  'neutral element': 7,
#  'map': 7,
#  'linear algebra': 6,
#  'audio signal': 6,
#  'resource': 6,
#  'product': 6,
#  'combination': 6,
#  'augmented': 6,
#  'left': 6,
#  'inverse element': 6,
#  'abelian': 6,
#  'linear': 6,
#  'hyperplane': 6,
#  'r3': 6,
#  'direction': 5,
#  'chapter': 5,
#  'closure': 5,
#  'linear\nequation': 5,
#  'line': 5,
#  'notation': 5,
#  'equation system': 5,
#  'gaussian elimination': 5,
#  'non-pivot column': 5,
#  'set': 5,
#  'abelian group': 5,
#  'b': 5,
#  'v;w': 5,
#  'homomorphism': 5,
#  'order': 5,
#  'composition': 5,
#  'afﬁne': 5,
#  'rule': 4,
#  'number': 4,
#  'algorithm': 4,
#  'machine learning': 4,
#  'illustration': 4,
#  'identity matrix': 4,
#  'ﬁrst column': 4,
#  'transform': 4,
#  'structure': 4,
#  'compute': 4,
#  'general linear group': 4,
#  'inner operation': 4,
#  'outer operation': 4,
#  'dependent': 4,
#  'vector space v': 4,
#  'minimal': 4,
#  'mapping \x08': 4,
#  'theorem': 4,
#  'b;c': 4,
#  'intuition': 3,
#  'result': 3,
#  'similarity': 3,
#  'datum': 3,
#  'chapter 9': 3,
#  'linear regression': 3,
#  'linear equation system': 3,
#  'third equation': 3,
#  'ﬁrst': 3,
#  'free': 3,
#  'solution space': 3,
#  'coefﬁcient': 3,
#  'computation': 3,
#  'diagonal': 3,
#  'ais': 3,
#  'regular': 3,
#  'ax=0': 3,
#  'zero': 3,
#  'right-hand side': 3,
#  'homogeneous system': 3,
#  'invertible': 3,
#  'associativity': 3,
#  'inhomogeneous': 3,
#  'kigali': 3,
#  'northwest': 3,
#  'southwest': 3,
#  'equivalent': 3,
#  'v': 3,
#  'stretch': 3,
#  'basis change': 3,
#  'v!w': 3,
#  'identity mapping': 3,
#  'null space': 3,
#  'afﬁne space': 3,
#  'afﬁne mapping': 3,
#  'exercise': 3,
#  'intuitive': 2,
#  'study': 2,
#  'abstract': 2,
#  'geometric': 2,
#  'interpret': 2,
#  'programming language': 2,
#  'algorithms': 2,
#  'linear\nalgebra:\nhttp://tinyurl': 2,
#  'scale': 2,
#  'strang': 2,
#  'liesen': 2,
#  'mehrmann\n(2015': 2,
#  'geometry': 2,
#  'projection': 2,
#  'problem': 2,
#  'linear\nalgebra': 2,
#  'optimal': 2,
#  'linear equation\nx1+x2+x3= 3': 2,
#  'redundancy': 2,
#  'empty': 2,
#  'intersection': 2,
#  'compact notation': 2,
#  'word': 2,
#  'chapter 4': 2,
#  'long vector': 2,
#  'size': 2,
#  'element-wise multiplication': 2,
#  'ab': 2,
#  'a\x001': 2,
#  'determinant': 2,
#  'inverse matrix': 2,
#  'transpose': 2,
#  'collection': 2,
#  'entry': 2,
#  'write': 2,
#  'symmetric matrix': 2,
#  'symmetric': 2,
#  'square matrix': 2,
#  'ax=b': 2,
#  'constant': 2,
#  'third column': 2,
#  'scaling': 2,
#  'general approach': 2,
#  'context': 2,
#  '\x003': 2,
#  'staircase': 2,
#  'pivot\ncolumn': 2,
#  'ﬁnde': 2,
#  'multiple': 2,
#  'col-\numn': 2,
#  'ﬁfth column': 2,
#  'identical': 2,
#  'simultaneous': 2,
#  'burlirsch': 2,
#  'iteration': 2,
#  'norm': 2,
#  'characterize': 2,
#  'g': 2,
#  'miss': 2,
#  'complex': 2,
#  'n-tuple': 2,
#  'vector\nspace': 2,
#  'person': 2,
#  'information': 2,
#  'statement': 2,
#  'km northwest': 2,
#  'blue': 2,
#  'column vector': 2,
#  'investigate': 2,
#  'linear\ncombination': 2,
#  'span': 2,
#  'ﬁnite-dimensional vector': 2,
#  'rk(a': 2,
#  'recall': 2,
#  'injective': 2,
#  'surjective': 2,
#  'bijective': 2,
#  'tuple': 2,
#  'linearity': 2,
#  'isomorphic': 2,
#  'isomorphism': 2,
#  'ann-dimensional vector space': 2,
#  'coordinate vector': 2,
#  'transformation matrix': 2,
#  'linear transformation': 2,
#  'rotation': 2,
#  'linear\nmapping \x08': 2,
#  'bandc': 2,
#  'change': 2,
#  'c.': 2,
#  'oftis': 2,
#  'replace with': 2,
#  'dim(im(\x08': 2,
#  'homogeneous equation system': 2,
#  'origin': 2,
#  'parameter': 2,
#  'translation': 2,
#  'topic': 2,
#  'rnf\x001g': 2,
#  'congruence': 2,
#  'integer': 2,
#  'u1\\u2': 2,
#  'calculate': 2,
#  'function': 2,
#  'symbol': 1,
#  'algebra': 1,
#  'school': 1,
#  'small arrow\nabove': 1,
#  'letter': 1,
#  'e.g.,\x00 !xand\x00 !': 1,
#  'bold': 1,
#  'xandy': 1,
#  'mathematical viewpoint': 1,
#  'high\nschool mathematic': 1,
#  'physic': 1,
#  'segment': 1,
#  '\x15!x,\x152r': 1,
#  'original vector\nscale by\x15.': 1,
#  'magnitude': 1,
#  'mathematical operation': 1,
#  'geometric\nvector\nand (b)': 1,
#  'unusual': 1,
#  'concrete': 1,
#  'sense previously': 1,
#  'rn(tuples': 1,
#  'triplet of number': 1,
#  'c2rn': 1,
#  'scale vector': 1,
#  '\x15a2rn': 1,
#  'rnhas': 1,
#  'beneﬁt': 1,
#  'implement': 1,
#  'array': 1,
#  'computer': 1,
#  'array operation': 1,
#  'con-\nvenient': 1,
#  'implementation': 1,
#  'vector concept': 1,
#  'largelypavel': 1,
#  'grinfeld’s\nseries': 1,
#  'rnsince': 1,
#  'for-\nmulate': 1,
#  'ﬁnite-\ndimensional vector': 1,
#  'array-based algorithm': 1,
#  'mathematic': 1,
#  'ques-\ntion': 1,
#  'lecture': 1,
#  'note': 1,
#  'book': 1,
#  'drumm\nand weil': 1,
#  'pavel grinfeld’s linear algebra series': 1,
#  'excellent': 1,
#  'solvesproperty ofmaximal set': 1,
#  'gilbert strang’s linear': 1,
#  'mit': 1,
#  'linear\nalgebra series': 1,
#  'gen-\neral mathematic': 1,
#  'ex-\npande': 1,
#  'chapter 3': 1,
#  'vector calculus': 1,
#  'op-\neration': 1,
#  'essential': 1,
#  'dimensionality': 1,
#  'reduction': 1,
#  'principal': 1,
#  'compo-\nnent analysis': 1,
#  'pca': 1,
#  'solve': 1,
#  'least-squares': 1,
#  'tool': 1,
#  'company': 1,
#  'n1;:::;nnfor': 1,
#  'r1;:::;rmare': 1,
#  'resourceriare': 1,
#  'objective': 1,
#  'plan': 1,
#  'xjof': 1,
#  'biunit': 1,
#  'ideally': 1,
#  'linear algebra\na total': 1,
#  'ri': 1,
#  'linear\nequation x1;:::;xnare': 1,
#  'n-tuple (x1;:::;xn)2\nrnthat satisﬁes': 1,
#  'i.e.,x3=': 1,
#  'plug': 1,
#  'triplet\n\x125\n2\x003\n2a;1\n2+1\n2a;a\x13': 1,
#  'inﬁnitely': 1,
#  'real-valued system': 1,
#  'version': 1,
#  'geometric interpretation': 1,
#  'linear equation\ndeﬁne': 1,
#  'x1x2-plane': 1,
#  'simultaneously': 1,
#  'intersection set': 1,
#  'three-dimensional\nspace': 1,
#  'systematic approach': 1,
#  'collect': 1,
#  'de-\nﬁne': 1,
#  'sec-\ntion': 1,
#  'linear\nfunction': 1,
#  'ﬁrst deﬁne': 1,
#  '(m;n)matrixais': 1,
#  'rectangular': 1,
#  'mrow': 1,
#  'row\ncolumn': 1,
#  'row/column vector': 1,
#  'column\nrow vector\ncolumn vector\nfigure 2.4 by\nstack its\ncolumn': 1,
#  'matrix a': 1,
#  '(m;n)-matrice': 1,
#  'a2rmnby': 1,
#  'stack': 1,
#  'addition': 1,
#  'element-\nwise sum': 1,
#  'cijof': 1,
#  'a': 1,
#  'compute element cijwe': 1,
#  'arencolumn\ninaandnrow': 1,
#  'bso': 1,
#  'dot\nproduct': 1,
#  'a\x01bto denote multiplication': 1,
#  'neighbor': 1,
#  'match': 1,
#  'n\x02k-matrixacan': 1,
#  'left side': 1,
#  'c|{z}\nn\x02m(2.14)': 1,
#  'productbais': 1,
#  'neighboring': 1,
#  'notdeﬁne': 1,
#  'element-wise operation': 1,
#  'matrix element': 1,
#  'a;bwas cho-\nsen': 1,
#  'multi-dimensional': 1,
#  'hadamard product': 1,
#  'hadamard product\nexample 2.3\nfora=\x141 2 3\n3 2 1\x15\n2r2\x023,b=2\n40 2\n1\x001\n0 13\n52r3\x022': 1,
#  'ab6=ba': 1,
#  'then\x02n-matrix': 1,
#  'ac+ad (2.19b)': 1,
#  'ima': 1,
#  'ain': 1,
#  'transpose\ndeﬁnition 2.3': 1,
#  'square matrix a2rn\x02n': 1,
#  'a\x001.': 1,
#  'apossesses': 1,
#  'sec-\nsingular\nnoninvertibletion': 1,
#  'existence': 1,
#  'matrix\na:=\x14a11a12\na21a22\x15\n2r2\x022:': 1,
#  'awith\na0:=\x14a22\x00a12\n\x00a21a11\x15\n(': 1,
#  'a11a22\x00a12a216=': 1,
#  'a11a22\x00\n \n2.2 matrix 25\na12a21i': 1,
#  'ba': 1,
#  'transpose ofa.': 1,
#  'a>. transpose': 1,
#  'principal diagonal",\n"primary diagonal",\n"lead diagonal",': 1,
#  'matrixais': 1,
#  'symmetric matrix\na=a>.\nnote': 1,
#  'ais invertible': 1,
#  'sum': 1,
#  'scalar\nlet we look': 1,
#  'then\x15a': 1,
#  'a. for\x15; 2r': 1,
#  'c=\x15( c);c2rm\x02n\n\x15(bc)': 1,
#  'b(\x15c': 1,
#  'all\x152r.distributivity\ndistributivity:\n(\x15+': 1,
#  'c=\x15c+': 1,
#  'c;c2rm\x02n\n\x15(b+c)': 1,
#  'distributivity': 1,
#  'linear equation\n2x1+ 3x2+ 5x3= 1\n4x1\x002x2\x007x3= 8\n9x1+': 1,
#  'x3the': 1,
#  'matrix form': 1,
#  'xjare unknown': 1,
#  'unknown': 1,
#  'deﬁne cito': 1,
#  'theith column': 1,
#  '[42;8;0;0]>.': 1,
#  'special\nsolution': 1,
#  'cca=\x151(8c1+ 2c2\x00c3': 1,
#  'reasoning': 1,
#  '0as\n\x141 0 8\x004\n0 1 2 12\x150\nbb@\x1522\n664\x004\n12\n0\n\x0013\n7751\ncca=\x152(\x004c1+ 12c2\x00c4': 1,
#  'ax=b.\n2': 1,
#  'general equation system': 1,
#  'constructive algorithmic': 1,
#  'transform\nany system': 1,
#  'gaussian\nelimination': 1,
#  'compact matrix\nnotationax=b.': 1,
#  'xexplicitly': 1,
#  'form\x02ajb\x03\n)': 1,
#  'augment': 1,
#  'vertical line': 1,
#  'left-hand side': 1,
#  'a+13\n775\x01(\x001)\n\x01(\x001\n3': 1,
#  '\x002 1\n0': 1,
#  'row-echelon form\n(ref': 1,
#  'revert': 1,
#  'explicit notation': 1,
#  'thegeneral solution': 1,
#  'pivots': 1,
#  'row\n(ﬁrst nonzero number': 1,
#  'equa-\ntion system': 1,
#  'row-echelon form)': 1,
#  'nonzero element': 1,
#  'nonzero row': 1,
#  'ﬁrst nonzero number': 1,
#  'lead coefﬁcient': 1,
#  'pivot\nlead coefﬁcient right of the': 1,
#  'basic': 1,
#  '}\nremark': 1,
#  'particular solution': 1,
#  'wherepi': 1,
#  '\x15iare': 1,
#  'rightmost pivot\ncolumn': 1,
#  '\x151;\x152;\x153so': 1,
#  'non-pivot column\nfor': 1,
#  '[2;0;\x001;1;0]>. }\nremark': 1,
#  '.an equation system': 1,
#  'row-reduced echelon form': 1,
#  'orrow': 1,
#  'canonical form': 1,
#  'sec-\ntion 2.3.3': 1,
#  'sys-\ntem of': 1,
#  'gaussian\nelimination remark': 1,
#  'row echelon form)\nverify': 1,
#  'ax=0is': 1,
#  'non-\npivot column': 1,
#  'row echelon': 1,
#  'ﬁrst pivot column': 1,
#  'and\x004time': 1,
#  'index': 1,
#  '\x004time': 1,
#  'homogeneous\nequation system': 1,
#  'ax=0;x2r5are': 1,
#  'practical': 1,
#  'read': 1,
#  'solu-\ntionsxof': 1,
#  'linear equation ax=0': 1,
#  'arbitrary real number': 1,
#  'ﬁrst\nnonzero entry per row': 1,
#  'corresponding\ncolumn': 1,
#  'standard unit vector': 1,
#  'ann\x02n-matrix': 1,
#  'homogeneous equation system ax=0': 1,
#  'kernel ornull space': 1,
#  'kernel\nnull space': 1,
#  'ref': 1,
#  'ax=0by\ntake the': 1,
#  'matrix x': 1,
#  'satisﬁesax': 1,
#  'ax': 1,
#  '\x02inja\x001\x03': 1,
#  'augmented equation system': 1,
#  'right-hand side:\na\x001=2\n664\x001 2\x002 2\n1\x001 2\x002\n1\x001 1\x001\n\x001 0\x001 23\n775:': 1,
#  'multi-\nplicationaa\x001and': 1,
#  'lin-\near equation': 1,
#  'solu-\ntion': 1,
#  'no solution': 1,
#  'approximate': 1,
#  'ap-\nproximate problem': 1,
#  'ax=bis': 1,
#  'asx': 1,
#  'mild': 1,
#  'aneeds': 1,
#  'space 35\nand use': 1,
#  'moore-penrose pseudo-inverse (a>a)\x001a>to': 1,
#  'moore-penrose\npseudo-inverse solution': 1,
#  'mini-\nmum norm least-square solution': 1,
#  'matrix-matrix product': 1,
#  'comput-\ne': 1,
#  'numerical precision': 1,
#  'pseudo-inverse': 1,
#  'brieﬂy': 1,
#  'deter-\nminant': 1,
#  'inde-\npendent (section 2.5': 1,
#  'arithmetic operation scale': 1,
#  'indirectly': 1,
#  'ei-\nther stationary iterative method': 1,
#  'richardson method': 1,
#  'ja-\ncobi method': 1,
#  'gauß-seidel method': 1,
#  'over-relaxation\nmethod': 1,
#  'krylov subspace method': 1,
#  'conjugate': 1,
#  'gradient': 1,
#  'gener-\nalized minimal residual': 1,
#  'biconjugate gradient': 1,
#  'book\nby': 1,
#  'stoer': 1,
#  'letx\x03be': 1,
#  'ax=b.': 1,
#  'iterative method': 1,
#  'residual': 1,
#  'kx(k+1)\x00x\x03kin': 1,
#  'matrix-vector notation': 1,
#  'structured space': 1,
#  'multiply': 1,
#  'type': 1,
#  'intact': 1,
#  'computer science': 1,
#  'code theory': 1,
#  'graphic': 1,
#  'setgand': 1,
#  'theng:=': 1,
#  'whereeis\nthe neutral element': 1,
#  'x\x001to denote': 1,
#  'abelian abelian group\ngroup': 1,
#  'commutative': 1,
#  '(n0;+)possesses': 1,
#  '(z;\x01)contain': 1,
#  'z2z;z6=\x061': 1,
#  'deﬁne componentwise': 1,
#  '(x1;\x01\x01\x01;xn)\x001:= (\x00x1;\x01\x01\x01;\x00xn)is': 1,
#  'rm\x02n;+': 1,
#  'ofm\x02n-matrices': 1,
#  'n\x02n-matrice with': 1,
#  '–closure': 1,
#  '–neutral element': 1,
#  'inis': 1,
#  '\x01" in(rn\x02n;\x01)': 1,
#  'ais regular': 1,
#  'a\x001i the\ninverse element': 1,
#  'a2rn\x02n': 1,
#  'gl(n;r': 1,
#  'gand inner operation': 1,
#  'inner/outer\noperation': 1,
#  'inner/outer product': 1,
#  'real-valued vector space': 1,
#  'setvwith': 1,
#  '(v;+)is vector\nthe zero vector': 1,
#  'vector vector': 1,
#  'outer operation scalar\n\x01is amultiplication': 1,
#  'vector multiplication': 1,
#  'theoret-\nically': 1,
#  'array multiplication': 1,
#  'program-\nming language': 1,
#  'stan-\ndard rule': 1,
#  'treat vector': 1,
#  'n\x021matrice\n \n38 linear algebra': 1,
#  'vector spaces': 1,
#  'allx;y2rn\n–multiplication': 1,
#  'a+b=2\n64a11+b11\x01\x01\x01a1n+b1n\n......\nam1+bm1\x01\x01\x01amn+bmn3\n75is': 1,
#  'ele-\nmentwise': 1,
#  'a;b2v\n–multiplication': 1,
#  '\x15a=2\n64\x15a11\x01\x01\x01\x15a1n\n......\n\x15am1\x01\x01\x01\x15amn3\n75as': 1,
#  'rm\x02ni': 1,
#  'rmn.': 1,
#  'standard deﬁnition': 1,
#  'standard vector': 1,
#  'scalar multiplication': 1,
#  'column vector column vector\nx=2\n64x1\n...\nxn3\n75': 1,
#  'rn\x021andr1\x02n(therow vector': 1,
#  'con- row vector\nfusion': 1,
#  'default': 1,
#  'col-\numn vector': 1,
#  'row vector': 1,
#  'transpose ofx.} transpose\n \n2.4 vector': 1,
#  'original': 1,
#  'dimensionality reduction': 1,
#  '(v;+;\x01)be': 1,
#  'andu\x12v': 1,
#  'u6=;.': 1,
#  'thenu=': 1,
#  'ofv(or vector subspace': 1,
#  'ifuis': 1,
#  'linear subspace\nand\x01restricted': 1,
#  'uofv.\nifu\x12v': 1,
#  'ertie': 1,
#  'vbecause': 1,
#  'x2v': 1,
#  'allx2u\x12v': 1,
#  'abelian group property': 1,
#  'tivity': 1,
#  'vwe': 1,
#  '8\x152r8x2u:\x15x2u': 1,
#  'vitself': 1,
#  'din figure': 1,
#  'r2(with': 1,
#  'inner/\nouter operation': 1,
#  'aandc': 1,
#  'bdoe\nnot': 1,
#  'linear equation ax=0\nwithnunknownsx=': 1,
#  'linear equation ax=\nb;b6=0is not': 1,
#  'r2are\nsubspace': 1,
#  'aand\nc': 1,
#  'bdoes': 1,
#  'linear algebra\nremark': 1,
#  'homo-\ngeneous system': 1,
#  'ax=0forx2rn.}\n2.5 linear independence\nin the': 1,
#  'vector\n(element': 1,
#  'ﬁnd\na set': 1,
#  'abasis': 1,
#  'linear\nindependence': 1,
#  'x1;:::;xk2v': 1,
#  'v2vof': 1,
#  'non-trivial linear combination': 1,
#  '\x15iin': 1,
#  'linear (in)dependence': 1,
#  'vwithk2nandx1;:::;xk2v': 1,
#  'bination': 1,
#  'i=1\x15ixiwith': 1,
#  '\x15i6= 0': 1,
#  'linearly dependent': 1,
#  'next section': 1,
#  'linearly dependent vector': 1,
#  'geographic': 1,
#  'nairobi': 1,
#  'kenya': 1,
#  'rwanda': 1,
#  'uganda': 1,
#  'sufﬁcient': 1,
#  'location': 1,
#  'geographic coordinate': 1,
#  'two-dimensional vector space': 1,
#  'ignore': 1,
#  'altitude': 1,
#  'earth’s curved': 1,
#  'surface': 1,
#  'tration': 1,
#  'purple': 1,
#  'southwest vector': 1,
#  'km west" vector': 1,
#  'black': 1,
#  'km west': 1,
#  'crude\napproximation': 1,
#  'de-\npendent': 1,
#  'setfx1;:::;xk': 1,
#  'column\nof a': 1,
#  'vec-\ntor': 1,
#  'row-echelon form\n\x141 3 0\n0 0 2\x15\n(2.66)': 1,
#  'sec-\nond column': 1,
#  'ﬁrst\ncolumn': 1,
#  'column\nbe pivot column': 1,
#  'column\n(': 1,
#  'general ap-\nproach': 1,
#  'row operation': 1,
#  'pivot\ncolumn:\n2\n6641 1\x001\n2 1\x002\n\x003': 1,
#  'vwithklinearly': 1,
#  'compact form': 1,
#  'testing': 1,
#  'whenpm\nj=1 jxj=0.': 1,
#  'mlinear combination': 1,
#  'kvectorsx1;:::;xk\nbe linearly': 1,
#  'b1;b2;b3;b42rnand\nx1=b1\x002b2+b3\x00b4\nx2=\x004b1\x002b2 + 4b4\nx3= 2b1': 1,
#  '3b2\x00b3\x003b4\nx4= 17b1\x0010b2+ 11b3+b4': 1,
#  'linear algebra\nbe linearly': 1,
#  'corre-\nsponde linear equation system': 1,
#  'coefﬁcient matrix\na=2\n6641\x004 2': 1,
#  'x4=\x007x1\x0015x2\x0018x3': 1,
#  'x4can': 1,
#  'athat\npossess': 1,
#  'v2vcan': 1,
#  'a.': 1,
#  'vcan': 1,
#  'x1;:::;xk': 1,
#  'ais generating set': 1,
#  'ifaspans': 1,
#  'speciﬁc': 1,
#  'b \x12': 1,
#  'bis': 1,
#  'v.\nbis': 1,
#  'maximal': 1,
#  'canonical/standard basis': 1,
#  'r3are\nb1=8\n<\n:2\n41\n0\n03\n5;2\n41\n1\n03\n5;2\n41\n1\n13\n59\n=': 1,
#  'b2=8\n<\n:2\n40:5\n0:8\n0:43\n5;2\n41:8\n0:3\n0:33\n5;2\n4\x002:2\n\x001:3\n3:53\n59\n=\n;:(2.79)': 1,
#  'a.\nremark': 1,
#  'vpossesse': 1,
#  'exam-\nple': 1,
#  'ofvis': 1,
#  'remark': 1,
#  'one-dimensional': 1,
#  'span[x1;:::;xm]\x12rncan': 1,
#  'matrix a\n2': 1,
#  'a.\n3': 1,
#  'associate with': 1,
#  'vector\nx1=2\n666641\n2\n\x001\n\x001\n\x0013\n77775;x2=2\n666642\n\x001\n1\n2\n\x0023\n77775;x3=2\n666643\n\x004\n3\n5\n\x0033\n77775;x4=2\n66664\x001\n8\n\x005\n\x006\n13\n777752r5;(2.81)': 1,
#  'u.\nfor': 1,
#  'form2\n666641 2 3\x001\n2\x001\x004 8\n\x001 1 3\x005\n\x001 2': 1,
#  'inde-\npendent': 1,
#  'linear equation \x151x1+\x152x2+\x154x4=0': 1,
#  'a2rm\x02n\nequal': 1,
#  'rank rank': 1,
#  'column rank equal': 1,
#  'row rank': 1,
#  'dim(u': 1,
#  'image orrange': 1,
#  'ato': 1,
#  'ofwcan': 1,
#  'linear equation\nsystemax=bcan': 1,
#  'augmented system': 1,
#  'ax=0possesse': 1,
#  'null kernel\nnull space space': 1,
#  'full-rank matrix': 1,
#  'less': 1,
#  'rank deﬁcient': 1,
#  'deﬁcient': 1,
#  'rows/column': 1,
#  'linear algebra\na=2\n41 2': 1,
#  'column\nbe 2': 1,
#  '\x08(y)': 1,
#  'allx;y2vand\x152r': 1,
#  'orvector space homomorphism': 1,
#  'linear mapping\nvector space': 1,
#  'sec-\ntion 2.7.1': 1,
#  'work': 1,
#  'arbitrary set': 1,
#  '\x08is call\ninjective\ninjective if8x;y2v': 1,
#  'y.surjective\nsurjective if\x08(v': 1,
#  'w.bijective\nbijective': 1,
#  'wcan': 1,
#  '\x08can': 1,
#  'linear\nmapping': 1,
#  'vandw:\nisomorphism\nisomorphism': 1,
#  'v!wlinear': 1,
#  'bijective endomorphism\nendomorphism': 1,
#  'v!vlinear automorphism\nautomorphism': 1,
#  'v!vlinear': 1,
#  'identity mapping oridentity identity mapping\nidentity\nautomorphismautomorphism': 1,
#  'i(x2+y2': 1,
#  '\x15\x08\x12\x14x1\nx2\x15\x13\n:\n(': 1,
#  'justiﬁes': 1,
#  'bijective linear mapping': 1,
#  'elementwise': 1,
#  'correspond-\ne addition': 1,
#  'bijection': 1,
#  '.finite-dimensional vector\nspacesvandware': 1,
#  'dim(v': 1,
#  'state': 1,
#  'bijective map': 1,
#  'incur': 1,
#  'loss': 1,
#  'justiﬁcation': 1,
#  'treat': 1,
#  'rm\x02n(the vector\nspace': 1,
#  'ofm\x02n-matrice': 1,
#  'bi-\njective mapping': 1,
#  '\x08': 1,
#  'anyn-dimensional vector space': 1,
#  'rn(theorem': 1,
#  'basisfb1;:::;bngof': 1,
#  'part': 1,
#  'unordered': 1,
#  'basisb=': 1,
#  '(b1;:::;bn)ofv.': 1,
#  'anyx2vwe': 1,
#  'b.': 1,
#  'coordinate vector\ncoordinate\nrepresentationordered': 1,
#  'b.\n \n2.7 linear mapping 51\na': 1,
#  'coordinate system': 1,
#  'e1;e2': 1,
#  'obtainx': 1,
#  'r2deﬁne': 1,
#  'rep-\nresentation': 1,
#  '(b1;b2)basis': 1,
#  'xwith': 1,
#  '(e1;e2)is[2;2]>.': 1,
#  '(e1;e2)ofr2': 1,
#  'coordinates1': 1,
#  '(b1;b2)(see figure': 1,
#  'b\nofv': 1,
#  'connection': 1,
#  'v;w\nwith': 1,
#  'c1;:::;cm': 1,
#  'v!w.': 1,
#  'forj2f1;:::;ng': 1,
#  'of\x08(with': 1,
#  'bofv': 1,
#  'andcofw': 1,
#  'cofw': 1,
#  'if^xis': 1,
#  'vto': 1,
#  'w.\nexample': 1,
#  'order basis b=\n(b1;:::;b3)ofvandc=': 1,
#  'matrix a\x08with': 1,
#  'bandcsatisﬁes': 1,
#  'linear\ntransformation': 1,
#  'dot': 1,
#  'stretching': 1,
#  'axis': 1,
#  'general linear\nmapping': 1,
#  'r2with\nthe transformation': 1,
#  'example': 1,
#  '400vector': 1,
#  'square': 1,
#  'matrix a1': 1,
#  'a2': 1,
#  'rectangle': 1,
#  'x1-coordinate': 1,
#  'original square': 1,
#  'reﬂection': 1,
#  'vand\nw.': 1,
#  'a\x082rm\x02nis': 1,
#  '~a\x082rm\x02n': 1,
#  'aand~aare': 1,
#  'how/': 1,
#  'c.\nremark': 1,
#  '(e1;e2)onto': 1,
#  'corre-\nspondingly': 1,
#  '\x141\n1\x15\n;\x141\n\x001\x15\n)': 1,
#  'diagonal transformation matrix': 1,
#  'a.\nin the': 1,
#  'explanation': 1,
#  'idvthat': 1,
#  'c.\nproof': 1,
#  'drumm': 1,
#  'weil': 1,
#  'c': 1,
#  'band\nt= (': 1,
#  'jth\ncolumn': 1,
#  'band\n \n2.7 linear mapping 55\nthekth column': 1,
#  'sandtare': 1,
#  'perspective': 1,
#  'comparing': 1,
#  'v(bis': 1,
#  '\x08cbis': 1,
#  'instantiation': 1,
#  'bonto linear combination': 1,
#  'c. assume': 1,
#  'a\x08\nof\x08cbwith': 1,
#  'bto~binvand fromcto~cinw': 1,
#  'cofw\n(': 1,
#  'basis\n~b;~cequivalently': 1,
#  'red': 1,
#  '\x04\x001\nc~cst\x001\n~a\x08a\x08vector space\norder basis': 1,
#  'ma-\ntrix': 1,
#  'b(inv': 1,
#  'cinw.': 1,
#  'linear mapping \x04~cc:w!w\nto map': 1,
#  'conto coordinate': 1,
#  '~cc\x0e\x08cb\x0e\tb~b= \x04\x001\nc~c\x0e\x08cb\x0e\tb~b': 1,
#  'identity': 1,
#  'map vector': 1,
#  'equivalence': 1,
#  's2rn\x02nandt2rm\x02m': 1,
#  'ma-\ntrice': 1,
#  'v!w\nand\t :w!xthe': 1,
#  'a\x08anda\tof the': 1,
#  'a\t\x0e\x08=a\ta\x08. }\nin light': 1,
#  'perspec-\ntive': 1,
#  'linear mapping \x08cb:v!w\nwith': 1,
#  'c.\nsis': 1,
#  'linear mapping \tb~b:v!v\n(automorphism': 1,
#  'ofb.': 1,
#  'v.\n \n2.7 linear': 1,
#  '\x04c~c:w!w\n(automorphism': 1,
#  'idwis\nthe': 1,
#  'w.\nif we': 1,
#  't\x001:c!~c': 1,
#  'execution': 1,
#  'r3!r4whose transformation matrix': 1,
#  'standard basis\nb=': 1,
#  'ith column': 1,
#  'b. sincebis': 1,
#  'co-\nordinate representation': 1,
#  '\x15isuch': 1,
#  'linear algebra\np3\ni=1\x15ibi=~bj,j= 1': 1,
#  'jth column': 1,
#  'coordi-\nnate': 1,
#  'domorphism': 1,
#  'datum compression problem': 1,
#  'project': 1,
#  'compression loss': 1,
#  'kernel\nthe': 1,
#  'cer-\ntain': 1,
#  'space kernel\nnull space\nker(\x08': 1,
#  '\x08( v)': 1,
#  'vandwthedomain andcodomain': 1,
#  'domain\ncodomain': 1,
#  'wherev;w': 1,
#  'v.\n \n2.7 linear mapping 59\nfigure': 1,
#  'kernel\nand': 1,
#  'v!wv w\n\x08is injective': 1,
#  'one-to-one': 1,
#  'a2rm\x02nand\na linear mapping \x08': 1,
#  'a1;:::;an': 1,
#  'column column space\nspace': 1,
#  'column space': 1,
#  'rm': 1,
#  'height': 1,
#  'kernel/null space ker(\x08': 1,
#  'rnthat': 1,
#  'width': 1,
#  'relationship': 1,
#  'whether/how': 1,
#  'span[\x141\n1\x15\n;\x142\n0\x15\n;\x14\x001\n0\x15': 1,
#  'ainto': 1,
#  'minus-\n1': 1,
#  'column 1and2': 1,
#  'lin-\near mapping \x08': 1,
#  'dim( v):': 1,
#  'rank-nullity theorem': 1,
#  'consequence': 1,
#  'non-trivial': 1,
#  'linear equation a\x08x=\n0ha': 1,
#  'afﬁne space 61\n2.8 afﬁne': 1,
#  'machine learning literature': 1,
#  'linear\nand afﬁne': 1,
#  'reference': 1,
#  'afﬁne\nspaces/mapping': 1,
#  'linear spaces/mapping': 1,
#  'x02vand\nu\x12va subspace': 1,
#  '2.130b': 1,
#  'afﬁne subspace orlinear manifold': 1,
#  'afﬁne subspace\nlinear manifold\ndirectiondirection space': 1,
#  'l\x12~lif': 1,
#  'u\x12~uandx0\x00~x02~u.\nafﬁne': 1,
#  'k-dimen-\nsional afﬁne space': 1,
#  'if(b1;:::;bk)is': 1,
#  'parametric equation parametric equation': 1,
#  'one-dimensional afﬁne subspace': 1,
#  'write line\nasy=x0+\x15b1': 1,
#  'one-\ndimensional subspace': 1,
#  'sup-\nport': 1,
#  'vectorb1that deﬁne': 1,
#  'rnare': 1,
#  'para- plane\nmetric equation': 1,
#  'where\x151;\x1522r\nandu=': 1,
#  'span[b1;b2]\x12rn': 1,
#  'direction space': 1,
#  'parametric equation': 1,
#  'x0+\x15b1lie': 1,
#  'inhomogeneous system': 1,
#  'fora2rm\x02nandx2rm': 1,
#  'linear equa-\ntionsa\x15': 1,
#  'rnof\ndimensionn\x00rk(a)': 1,
#  '(\x151;:::;\x15n)6=': 1,
#  'hyperplane\ninrn.': 1,
#  'everyk-dimensional afﬁne subspace': 1,
#  'linear equation ax=b': 1,
#  'wherea2rm\x02n;b2\nrmandrk(a)': 1,
#  'n\x00k': 1,
#  'read 63\nmapping \x08': 1,
#  'vectorais': 1,
#  'geometric structure invariant': 1,
#  'parallelism': 1,
#  'reading': 1,
#  'learn linear algebra': 1,
#  'golan': 1,
#  'axler': 1,
#  'liesen and\nmehrmann': 1,
#  'online': 1,
#  'introduction': 1,
#  'gaussian elim-\nination': 1,
#  'solve system': 1,
#  'numerical linear algebra textbook': 1,
#  'horn and\njohnson': 1,
#  'discussion': 1,
#  'linear independence': 1,
#  'inner\nproduct': 1,
#  'induce': 1,
#  'length': 1,
#  'distance': 1,
#  'orthogonal': 1,
#  'pro-\njection': 1,
#  'principal component analysis': 1,
#  'linear algebra\nexercise': 1,
#  'a;b2rnf\x001g': 1,
#  'letnbe innnf0g. letk;xbe': 1,
#  'deﬁne z=nz(sometime write zn': 1,
#  'euclidean division': 1,
#  'ﬁnite set': 1,
#  'con-\ntainingnelement:\nzn=f0;1;:::;n\x001g\nfor alla;b2zn': 1,
#  ...}

# %%
# calculating similarity
import numpy as np
from numpy.linalg import norm
def find_most_similar(word, df_entities):
    try:
        word_embedding = df_entities.loc[df_entities.lemma == word,"embedding"].mean()
        rest = (df_entities.loc[df_entities.lemma != word,["lemma","embedding"]]
                .groupby("lemma").mean()
                .reset_index()
            )
        rest_embeddings = rest["embedding"].values
        rest_entities = rest["lemma"].values

        cosine_similarity = []
        for embedding in rest_embeddings:
            cosine_similarity.append(embedding @ word_embedding / (norm(embedding)*norm(word_embedding)+10e-10))
        best = np.array(cosine_similarity).argsort()[-5:][::-1]
        return rest_entities[best]
    except:
        print("This word is not included in the dataset")

# %%
find_most_similar("matrix", df_entities)
# Out:
# array(['matrix a\x08with', 'matrix form',
#        'r3!r3whose transformation matrix',
#        'r3!r4whose transformation matrix', 'full-rank matrix'],
#       dtype=object)

# %%
find_most_similar("vector", df_entities)
# Out:
# array(['rn\x021andr1\x02n(therow vector', 'vector vector',
#        'ﬁnite-dimensional vector',
#        '.finite-dimensional vector\nspacesvandware',
#        '(v;+)is vector\nthe zero vector'], dtype=object)

# %%
find_most_similar("determinant", df_entities)
# Out:
# array(['consequence', 'context', 'function', 'essential',
#        'principal component analysis'], dtype=object)

# %%
find_most_similar("inverse", df_entities)
# Out:
# array(['inverse element', 'linear\nalgebra', 'linear\nmapping',
#        'linear spaces/mapping', 'linear equa-\ntionsa\x15'], dtype=object)

# %% [markdown]
# #### Conclusion:
#
# 1. NER: en_core_sci_md model identifies entities quite well, even if it was trained on biomedical data. However, some subsequent filtering is required.
#
# 2. Cosine similarity between word embeddings does not allow finding most similar concepts supposedly for the following reasons:
#
# - corpus is small
#
# - noise in data like '.finite-dimensional vector\nspacesvandware' and etc.
#
# - need to check "the meaning" of vectors, maybe I misused them
#
# - averages of the vectors may not represent a "real" vector/embedding of a word in the vector space.

# %% [markdown]
# ## SciBert, only transformers library

# %%
from transformers import BertTokenizer, BertForTokenClassification, pipeline

tokenizer = BertTokenizer.from_pretrained('allenai/scibert_scivocab_uncased')
model = BertForTokenClassification.from_pretrained('allenai/scibert_scivocab_uncased')
nlp = pipeline('ner', model=model, tokenizer=tokenizer)
# Out:
# Some weights of the model checkpoint at allenai/scibert_scivocab_uncased were not used when initializing BertForTokenClassification: ['cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of BertForTokenClassification were not initialized from the model checkpoint at allenai/scibert_scivocab_uncased and are newly initialized: ['classifier.weight', 'classifier.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
doc = nlp(data.text["Linear Algebra"][:1000])

# %%
doc[:5]
# Out:
# [{'entity': 'LABEL_1',
#   'score': 0.5618813,
#   'index': 1,
#   'word': 'when',
#   'start': None,
#   'end': None},
#  {'entity': 'LABEL_0',
#   'score': 0.6189762,
#   'index': 2,
#   'word': 'formal',
#   'start': None,
#   'end': None},
#  {'entity': 'LABEL_0',
#   'score': 0.5179148,
#   'index': 3,
#   'word': '##izing',
#   'start': None,
#   'end': None},
#  {'entity': 'LABEL_0',
#   'score': 0.55187863,
#   'index': 4,
#   'word': 'intuitive',
#   'start': None,
#   'end': None},
#  {'entity': 'LABEL_0',
#   'score': 0.52490836,
#   'index': 5,
#   'word': 'concepts',
#   'start': None,
#   'end': None}]

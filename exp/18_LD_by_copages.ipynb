# %% [markdown]
# This experiment deals with the co-occurence of concepts on the same page or surrounding pages. It is based on the assumption that dependencies are used within close proximity.
# Pseudo-algorithm:
# 1. For each concept: Find all other concepts that are 1. introduced before but 2. mentioned again within proximity of the introduction of the concept (1-2 page padding).

# %%
import pandas as pd
import numpy as np
from collections import Counter
import sys
sys.path.append('../src/')
import data_layer

# %%
MAX_K=5
PAGES_BEFORE=3
PAGES_AFTER=3

# %%
book_indices, wiki_concepts = data_layer.read_index_and_wiki_concepts()

# %%
def get_page_list(page_string):
    if not isinstance(page_string, float) and "nan" in page_string: return []
    pages = [page_string] if isinstance(page_string, float) else page_string.split(",")
    return [int(page) for page in pages]

def get_df_page_concepts(wiki_concepts, wiki_pages):
    page_nums=[]
    concepts=[]
    for concept, pages in zip(wiki_concepts, wiki_pages):
        for page in get_page_list(pages):
            page_nums.append(page)
            concepts.append(concept)
    return pd.DataFrame({"page": page_nums, "concept": concepts})

# %%
potential_deps = {concept: [] for concept in wiki_concepts}

for book, index in book_indices.items():
    first_page = {concept: int(pages[0]) for concept, pages in zip(index.wiki_concept, index.pages)}
    df_pages = get_df_page_concepts(index.wiki_concept, index.pages)

    for concept, page in zip(index.wiki_concept, index.first_page):
        deps = list(df_pages.loc[(df_pages.page > page - PAGES_BEFORE) & (df_pages.page < page + PAGES_AFTER),"concept"])
        deps.remove(concept)
        potential_deps[concept] += deps

# %%
def get_frequent(deps):
    c = Counter(deps)
    return [d[0] for d in c.most_common(MAX_K) if c[d[0]]>1]

df_concepts = pd.DataFrame({'concept': potential_deps.keys(), 'dep_articles': [get_frequent(deps) for deps in potential_deps.values()]})

# %%
for c, d in zip(df_concepts.concept, df_concepts.dep_articles):
    print(f"{c}: {d}")
# Out:
# Jacobi operator: ['Inner product space']
# Inverse hyperbolic functions: []
# Substitution cipher: ['System of linear equations']
# List of numerical analysis topics: []
# History of the function concept: []
# Rotation (mathematics): ['Euler angles', 'Hadamard matrix']
# Fibonacci: ['Recurrence plot']
# Random number generation: []
# Empty set: ['Union (set theory)', 'Vector notation', 'Set (mathematics)', 'Subset', 'Ring (mathematics)']
# Electromagnetic tensor: []
# Parabola: []
# Regression analysis: []
# Mind map: []
# Antiunitary operator: []
# Vertical line test: []
# Precision (computer science): ["Gauss's method", 'Data analysis']
# Householder transformation: []
# Autonomous system (mathematics): ['System of linear equations', 'Consistency', 'Ω-consistent theory']
# Asymptote: ['Vertical tangent']
# Chemical reaction network theory: []
# Critical exponent: ['Complex number']
# Fast Fourier transform: []
# Group testing: []
# Fermat's principle: []
# Spectral density: []
# Universal approximation theorem: []
# Equation: ['Vacuum solution (general relativity)', 'Line (geometry)']
# Proportionality (mathematics): ['Bounded variation', 'Inverse problem']
# Gauss map: []
# Parity of a permutation: []
# Euclidean distance: ['Orthogonal matrix', 'Orthonormal basis', 'Congruence (geometry)']
# Electrical network: ['Junction Grammar']
# Leading-order term: ['Coefficient', 'Degree (graph theory)', 'Order of a polynomial', 'Polynomial']
# Element (mathematics): ['Elementary mathematics', 'System of linear equations']
# Nonlinear dimensionality reduction: []
# Eigendecomposition of a matrix: ['Eigenvalues and eigenvectors', 'Matrix (mathematics)', 'Matrix multiplication', 'Diagonalizable group', 'Similarity invariance']
# Riemann–Roch theorem: ['Affine transformation', 'Lorentz transformation']
# Variation of parameters: ["Cramer's rule"]
# Anti-diagonal matrix: ['Matrix decomposition']
# Musical isomorphism: ['Isomorphism']
# Lagrange polynomial: ['Vandermonde matrix', 'Coefficient', "Cramer's rule"]
# Isaac Newton: ['Canonical form', 'Echelon formation', 'Elementary matrix', 'Hermite normal form', 'Matrix decomposition']
# Mathematics: ['System of linear equations', 'Numerical methods for ordinary differential equations', 'Variable (mathematics)', 'Coriolis force', 'Conic section']
# Arithmetic: []
# Edge contraction: ['Matrix multiplication']
# Nonnegative matrix: ['Matrix addition', 'Pauli matrices', 'Scalar multiplication']
# Radius: []
# Bounded operator: []
# Inverse function theorem: []
# Vandermonde matrix: ['Matrix exponential', 'Block matrix', 'Determinant']
# Principal value: ['Complex number', 'Split-complex number', 'Complex plane', 'Imaginary unit', 'Real number']
# Titanic (1997 film): []
# Non-negative matrix factorization: ['Matrix equivalence', 'Partition function (mathematics)']
# Tensor: ['Gaussian elimination', 'System of linear equations']
# Steinitz exchange lemma: ['Linear independence']
# Mathematical proof: []
# String theory: ['Nilpotent', 'Nilpotent matrix']
# Composition of relations: ['Matrix multiplication']
# Markov chain: ['State-transition matrix', 'Transition kernel', 'Linear equation']
# Cauchy theorem: ['Determinant']
# Decoding methods: ['Code']
# Axiom: ['Complex number']
# Scattering: ['Correlation']
# Natural logarithm: []
# Symmetric bilinear form: ['Barrier function']
# Fractal: []
# Homological algebra: []
# Electrostatics: ['Local optimum']
# Invertible knot: ['Determinant', 'Skew-symmetric matrix']
# Gram–Schmidt process: ['Orthonormal basis', 'Orthogonality (mathematics)', 'Orthogonal matrix', 'Linear equation']
# Cam: ['Euclidean algorithm', 'Modulo (mathematics)']
# Relation (mathematics): []
# Tetrahedron: []
# Sard's theorem: ['Basis (linear algebra)']
# Exponential decay: ['Exponential growth']
# Transformation matrix: ['Affine transformation', 'Matrix (mathematics)', 'Triangular matrix']
# Directed graph: ['Matrix multiplication', 'Pattern Blocks']
# Euclidean geometry: []
# Minimum spanning tree: []
# Set (mathematics): ['Bijection', 'Empty set', 'Subset', 'Image (mathematics)', 'One-to-one (data model)']
# Correlation: []
# Normal basis: ['Free module']
# Sum: ['Standard basis']
# Exotic sphere: ['Coefficient', 'Sign function']
# Change of variables: []
# Cesàro summation: ['Series (mathematics)', 'Summation']
# Antiparallel (mathematics): ['Line (geometry)']
# Cauchy sequence: ['Quadratic formula', 'Integer sequence', 'Sequence']
# Fisher transformation: ['Affine transformation']
# If and only if: ['Matrix (mathematics)', 'Matrix addition', 'Pauli matrices', 'Rotation matrix', 'Triangular matrix']
# Transitive relation: ['Constant-recursive sequence', 'Linear congruential generator']
# Point-biserial correlation coefficient: ['Correlation', 'Mathematics']
# Bijection: ['Differentiable function', 'One-to-one (data model)', 'Set (mathematics)', 'Image (mathematics)', 'Canonical form']
# Creation and annihilation operators: []
# Tensor operator: ['Mathematical proof', 'Triangular matrix']
# Antipodal point: ['Projective geometry', 'Homogeneous coordinates', 'Projective plane', 'Vanish at infinity']
# Counterexample: ['Canonical form', 'Echelon formation', 'Elementary matrix', 'Hermite normal form', 'Matrix decomposition']
# Multiplicity (mathematics): ['Polynomial', 'Eigenvalues and eigenvectors', 'Multiset', 'Eigenvalue algorithm', '0']
# Weyl tensor: ['Vector space']
# Look-and-say sequence: ['Constant-recursive sequence', 'Linear congruential generator']
# Semisimple Lie algebra: []
# Diophantine geometry: []
# Piecewise linear function: []
# Reflection (mathematics): ['Linear map', 'Affine transformation', 'Rotation (mathematics)']
# Cyclic subspace: []
# Cyclic permutation: ['Elementary matrix', 'Gaussian elimination']
# Concave function: ['Local optimum']
# Pythagorean theorem: ['Vector notation', 'Real coordinate space', 'Y-intercept']
# Jordan measure: []
# Ordered field: ['System of linear equations']
# Real coordinate space: ['Vector notation', 'Cross product', 'Matrix multiplication', 'Unit vector']
# Distributive lattice: ['Matrix multiplication', 'Scalar multiplication']
# Complex conjugate of a vector space: []
# Orientation character: ['Orthogonal matrix', 'Orthonormal basis']
# Trinomial expansion: []
# Analytic function: ['Vector space']
# Woodbury matrix identity: ['Symmetric matrix']
# Implicit function: ['Parametric surface']
# Null set: ['Linear subspace', 'Kernel (image processing)', 'Minkowski space', 'Linear map', 'Image (mathematics)']
# Similarity (geometry): ['Linear equation', 'Matrix equivalence']
# Orthographic projection: ['Orthogonal complement', 'Projection (linear algebra)', 'Projection (mathematics)', 'Orthogonality (mathematics)', 'Orthographic projection']
# Square root of a matrix: ['Orthogonal matrix', 'Transformation matrix']
# Order of operations: ['Matrix multiplication', 'Module (mathematics)', 'Examples of vector spaces', 'Associative property', 'Commutative property']
# Complex conjugate root theorem: ['Complex number', 'Fundamental theorem of algebra', 'Weierstrass factorization theorem']
# Random walk: []
# Arrows (Unicode block): []
# Singular value decomposition: ['Singular value', 'Linear independence']
# Natural transformation: []
# Inner product space: ['Vector notation', 'Geometric algebra', 'Geometric series', 'Unit vector', 'Norm (mathematics)']
# Noether's theorem: ['System of linear equations']
# Vector calculus: ['Euclidean vector', 'Vector space', 'Vector notation', 'Matrix (mathematics)', 'Vector (mathematics and physics)']
# Matrix splitting: ["Horner's method", 'Mathematics']
# Color space: []
# Canonical form: ['Echelon formation', 'Matrix (mathematics)', 'Row equivalence', 'Distance matrix', 'Elementary mathematics']
# Giuseppe Peano: ['Vector space']
# Set theory: ['Definition', 'Set-builder notation', 'Union (set theory)', 'Venn diagram', 'Linear regression']
# Doubly stochastic matrix: []
# Universal property: ['Unit vector']
# Polar space: ['Complex number', 'Complex plane']
# Continued fraction: ['Triangular matrix', 'Partial fraction decomposition', 'Regular expression']
# Line (geometry): ['Vector (mathematics and physics)', 'Hyperplane', 'Euclidean vector', 'Vector space']
# Symmetric group: []
# Orientation (geometry): ['Sense', 'Size', 'Volume']
# Evaluation: []
# Rigid rotor: ['Orthogonal matrix', 'Orthonormal basis', 'Congruence (geometry)']
# Indian mathematics: ['Homomorphism', 'Ring homomorphism']
# Real projective line: []
# Chromatic polynomial: []
# Dyadic rational: ['System of linear equations']
# Associative property: ['Vector space', 'Commutative property', 'Matrix multiplication']
# Homogeneous coordinates: ['Numerical methods for ordinary differential equations', 'System of linear equations', 'Orientation character', 'Orthogonal matrix', 'Orthonormal basis']
# Diophantine equation: ['System of linear equations', 'Vector space']
# Vector space: ['System of linear equations', 'Vector (mathematics and physics)', 'Euclidean vector', 'Matrix (mathematics)', 'Vector space']
# Mathematical and theoretical biology: ['Junction Grammar']
# Cartan matrix: ['Jordan matrix', 'Jordan normal form', 'Markov chain']
# Reductionism: ['Euclid']
# Binary code: ['Code', 'Coding theory', 'Gray code', 'Hamming distance']
# Congruence (geometry): ['Orthogonal matrix', 'Orthonormal basis', 'Mathematics']
# Domain (mathematical analysis): []
# Cayley graph: ['Matrix (mathematics)', 'Triangular matrix', 'Minimal polynomial (field theory)']
# Knowledge economy: ['Input–output model']
# Simultaneous equations model: []
# Anthropic principle: []
# Molecular dynamics: ["Schur's theorem", 'Triangular matrix']
# GJMS operator: []
# Indefinite inner product space: ['Inner product space']
# Regular representation: ['Invariant subspace']
# Right triangle: ['Orthogonal matrix', 'Orthonormal basis', 'Orientation character']
# Permutation test: ['Sign (mathematics)']
# Group representation: ['Basis (linear algebra)']
# Golden rectangle: []
# Convergence of random variables: ['Principal component analysis']
# Moore–Penrose inverse: ['Invertible matrix', 'Mathematics']
# Row equivalence: ['Distance matrix', 'Matrix (mathematics)', 'Gaussian elimination', 'Row equivalence', 'Canonical form']
# Apollonius of Perga: []
# Wavelet transform: []
# Complement (set theory): []
# Central line (geometry): ['Mathematics']
# Recurrence relation: ['Linear equation']
# Diagonally dominant matrix: ['Transpose']
# Subtraction: ['Matrix addition', 'Pauli matrices', 'Scalar multiplication']
# Differential equation: ['Delay differential equation']
# Fisher's exact test: ['Linear independence']
# Map projection: ['Orthogonal matrix', 'Orthonormal basis', 'Congruence (geometry)']
# Affine transformation: ['Lorentz transformation', 'Transformation matrix', 'Affine transformation', 'Transformation (function)', 'Vector space']
# Geometric progression: ['System of linear equations', 'Distance matrix']
# Jacobi identity: []
# Triangulation (topology): ['Annihilator (ring theory)', 'Conductor (class field theory)']
# Quantum dynamics: ['Isomorphism', 'Automorphism', 'Function composition']
# Initial condition: ['Delay differential equation', 'Differential equation', 'Vector (mathematics and physics)']
# Multiview orthographic projection: ['Nonlinear dimensionality reduction']
# Total internal reflection: []
# Basis of a matroid: []
# Sesquilinear form: []
# Knapsack problem: []
# P-Laplacian: []
# Disquisitiones Arithmeticae: ['Canonical form', 'Echelon formation', 'Elementary matrix', 'Hermite normal form', 'Matrix decomposition']
# Vector (mathematics and physics): ['Vector notation', 'Euclidean vector', 'System of linear equations', 'Distance matrix', 'Unit vector']
# Noncommutative ring: []
# Vanishing point: ['Projective geometry', 'Abstraction (mathematics)']
# Linear independence: ['Linear independence', 'Closure (mathematics)', 'Vector space', 'Linear span', 'Linear subspace']
# Reciprocal polynomial: ['Canonical form']
# Hyperplane: ['System of linear equations', 'Consistency', 'Line (geometry)', 'Ω-consistent theory', 'Distance matrix']
# Lorentz group: []
# Scale parameter: ["Gauss's method", 'Condition number', 'Flow network']
# Proper orthogonal decomposition: ['Orthographic projection']
# Computer graphics (computer science): ['Homogeneous coordinates', 'Computer graphics (computer science)']
# Zorn's lemma: []
# Hessenberg matrix: []
# Pseudo-reductive group: []
# Commutative algebra: []
# Exponent (disambiguation): ['Associative property', 'Commutative property']
# Data transformation (statistics): []
# Maximum principle: ['Symmetry (geometry)']
# Arc length: ['Matrix multiplication', 'Pattern Blocks']
# Leslie matrix: []
# Sherman–Morrison formula: []
# Icon (computing): []
# Commutative ring: ['Split-complex number', 'Additive identity', 'Complex number', 'Mathematics']
# Recursive language: ['Recurrence plot']
# Spin (physics): ['Paradox']
# Magnetic vector potential: []
# Archimedes: ['Canonical form', 'Echelon formation', 'Elementary matrix', 'Hermite normal form', 'Matrix decomposition']
# Integer: ['Field (mathematics)', 'Scalar (mathematics)', 'System of linear equations', 'Euclidean algorithm', 'Modulo (mathematics)']
# Generation of primes: []
# Polygon triangulation: []
# Metric space: ['Affine transformation']
# Gram matrix: ['Singular value']
# Separable space: ['Nilpotent']
# Contradiction: ['Euclid']
# Minkowski addition: []
# Taxicab geometry: ['Unit vector', 'Vector space']
# Compact operator on Hilbert space: []
# Homogeneity (disambiguation): []
# Cramer's rule: ['Determinant', "Cramer's rule", 'Adjugate matrix', 'Invertible matrix', 'Matrix (mathematics)']
# Vector graphics: ['Correlation']
# Euler method: ['Eigendecomposition of a matrix', 'Orthogonal matrix']
# Orthogonality (mathematics): ['Vector notation', 'Real coordinate space', 'Unit vector', 'Dot product', 'Orthographic projection']
# Kronecker symbol: []
# Newton's law of cooling: ['Exponential growth']
# Isomorphism theorems: []
# Drinfeld module: ['Free module']
# Additional Mathematics: []
# Fredholm operator: []
# Bogoliubov transformation: ['Affine transformation', 'Lorentz transformation']
# Random variable: ['System of linear equations', 'Function (mathematics)', 'Substitution (logic)', 'Variable (mathematics)', 'Affine transformation']
# Number: ['Imaginary unit', 'Complex number', 'System of linear equations']
# Particle swarm optimization: ['Barrier function']
# Matrix representation: ['Hadamard matrix']
# Differential-algebraic system of equations: ['Numerical methods for ordinary differential equations', 'System of linear equations']
# Intersection (set theory): ['Union (set theory)', 'Empty set', 'Definition', 'Set-builder notation', 'Venn diagram']
# Equivalence relation: ['Gamma matrices', 'Diagonal', 'Diagonal matrix', 'Diagonalizable group', 'Eigenvalues and eigenvectors']
# Shear matrix: ['Affine transformation', 'Dilation (morphology)', 'Geometric transformation']
# Least-squares spectral analysis: []
# Basia: ['Dual space']
# Bounded inverse theorem: []
# Scalar boson: []
# Flow network: ['Condition number', 'Flow network', "Gauss's method"]
# Factor analysis: []
# Bracket: []
# Division sign: []
# Poietic Generator: []
# Stochastic matrix: ['Markov chain', 'Stochastic matrix', 'Input–output model', 'S-box']
# Definable: ['Direct sum', 'Direct sum of groups']
# Basis (linear algebra): ['Dimension', 'Basis (linear algebra)', 'Standard basis', 'Change of basis', 'Dimension (vector space)']
# Common logarithm: []
# Inverse function rule: ['Generalized inverse', 'Inverse function', 'Multiplicative inverse']
# Frobenius inner product: ['Inner product space', 'Norm (mathematics)']
# Linear programming: ['Principal component analysis']
# Simple harmonic motion: []
# Logarithmic growth: []
# Product rule: []
# Self-adjoint operator: ['Linear subspace']
# Economic system: ['Input–output model']
# Globalization: ['Global optimization']
# Round-off error: ["Gauss's method", 'Triangular matrix', 'Condition number', 'Precision (computer science)']
# Interest rate: []
# Nonlinear system: ['Recurrence relation', 'Recurrence plot']
# Computational science: ['Eigendecomposition of a matrix', 'Euler method', 'Orthogonal matrix']
# Weyr canonical form: []
# Distribution (mathematics): ['Principal component analysis']
# Invariance of domain: ['Standard basis']
# Note-taking: []
# Image (mathematics): ['Differentiable function', 'Linear subspace', 'Null set', 'Set (mathematics)', 'Vector notation']
# Legendre polynomials: ["Horner's method", 'Mathematics', 'Matrix norm']
# Right ascension: []
# Field (mathematics): ['Scalar multiplication', 'Vector space', 'Euclidean vector', 'Vector (mathematics and physics)', 'Power associativity']
# Semisimple operator: []
# Einstein field equations: []
# Signed distance function: ['Affine transformation', 'Cartesian coordinate system', 'Coordinate system']
# Coordinate system: ['Cartesian coordinate system', 'Projective geometry', 'Axis', 'Origin (mathematics)', 'Y-intercept']
# Interpolation: []
# Negative number: ['Matrix multiplication', 'Vector notation', 'Scatter plot']
# Adjoint: ['Adjugate matrix', 'Matrix (mathematics)', 'Laplace expansion', 'Invertible matrix', 'Determinant']
# Indexed family: []
# Coprime integers: ['System of linear equations']
# Identity matrix: ['Square matrix', 'Matrix (mathematics)', 'Identity matrix', 'Matrix decomposition', 'Row equivalence']
# Monte Carlo method: []
# The Doctor (Doctor Who): []
# Alternating permutation: []
# Dimension: ['Basis (linear algebra)', 'Vector space', 'Dimension (vector space)', 'Linear span', 'Standard basis']
# Differentiable function: ['Delay differential equation', 'Differential equation', 'Linear map']
# French curve: []
# Circle: []
# Legendre function: ['Orthonormal basis']
# Unit fraction: ['Geometric series', 'Euclidean vector', 'Geometric algebra', 'Unit vector', 'Vector (mathematics and physics)']
# Plane (geometry): []
# Positive-definite function: ['Inner product space']
# Wave equation: []
# Complex plane: ['Complex number', 'Split-complex number', 'Imaginary unit', 'Absolute value', 'Complex conjugate']
# Lancaster University: ['Input–output model']
# Shift space: []
# Timeline of manifolds: ['Annihilator (ring theory)', 'Conductor (class field theory)']
# Kindergarten: ['Euclidean vector']
# Laplace expansion: ['Determinant', 'Minor (linear algebra)', 'Matrix (mathematics)', 'Matrix calculus', 'Linear equation']
# Sign function: ['Linear subspace', 'Vector space', 'Fourier series', 'Permutation', 'Function (mathematics)']
# Invariant (mathematics): ['Nilpotent', 'System of linear equations', 'Variable (mathematics)', 'Eigenface', 'Consistency']
# Uniform space: ['Nilpotent']
# Doubling time: ['Exponential decay', 'Exponential growth']
# Dilation (morphology): ['Affine transformation', 'Isomorphism', 'Matrix multiplication', 'Shear matrix', 'Automorphism']
# Vector space model: ['Matrix multiplication']
# Numbers (season 5): ['Linear independence']
# Orthogonal array: []
# Condition number: ["Gauss's method", 'Flow network']
# Polarization identity: []
# Orthogonal group: ['Orthogonal matrix', 'Orthogonal coordinates', 'Orthogonal functions', 'Principal axis theorem']
# Parallel (operator): ['Flow network', 'Conservation law', 'Euclidean vector', 'Geometric algebra', 'Vector space']
# Zero matrix: ['Matrix (mathematics)', 'Matrix addition', 'Matrix multiplication', 'Matrix norm', 'Pauli matrices']
# Slope: ['Linear map', 'Affine transformation', 'Dilation (morphology)']
# Harmonic scale: []
# Velocity: ['Euclidean vector', 'Geometric algebra', 'Geometric series', 'Unit vector', 'Vector (mathematics and physics)']
# Characterization (mathematics): ['Matrix equivalence', 'Partition function (mathematics)']
# Solver: ['Triangular matrix']
# Linear system: ['Vector space']
# Scalar (mathematics): ['Vector space', 'System of linear equations', 'Matrix addition', 'Scalar multiplication', 'Mathematics']
# Partial differential equation: ['Outer product']
# Gaussian elimination: ['System of linear equations', 'Numerical methods for ordinary differential equations', 'Elementary mathematics', 'Linear combination', 'Block-stacking problem']
# Recurrence plot: ['Laplace expansion', 'Adjugate matrix', 'Matrix (mathematics)']
# Discriminant: ['Quadratic formula', 'Pythagorean theorem']
# Hamming bound: ['Code', 'Coding theory', 'Gray code', 'Hamming distance']
# Flatland: ['Mathematics']
# Tangent: []
# Quadrant (plane geometry): ['Cartesian coordinate system', 'Coordinate system', 'Axis', 'Ordered pair', 'Origin (mathematics)']
# Primary decomposition: []
# Restriction (mathematics): ['Invariant subspace', 'Triangular matrix']
# Chinese remainder theorem: []
# Rigid analytic space: []
# Least-squares adjustment: []
# Additive inverse: ['Vector space', 'Euclidean vector', 'Scalar multiplication', 'Vector (mathematics and physics)']
# Hyperspace: ['Dual space']
# Complexification: []
# Linear combination: ['System of linear equations', 'Numerical methods for ordinary differential equations', 'Triviality (mathematics)', 'Symmetric matrix', 'Gaussian elimination']
# Economic model: ['Input–output model']
# Riffle shuffle permutation: []
# Inductive reasoning: []
# Four-dimensional space: ['Gaussian elimination']
# Homology (mathematics): []
# Inverse function: ['Generalized inverse', 'Matrix (mathematics)', 'System of linear equations', 'Inverse function', 'Multiplicative inverse']
# Reflection group: []
# Schur decomposition: ['Characteristic polynomial', 'List of unsolved problems in mathematics']
# Euclidean space: []
# Atmospheric lidar: []
# Euclidean vector: ['Vector (mathematics and physics)', 'Vector space', 'Euclidean vector', 'Unit vector', 'Matrix (mathematics)']
# Component (graph theory): []
# History of logarithms: ['History of logarithms']
# Ohm's law: ['Flow network', 'Mathematical and theoretical biology', 'Condition number']
# QR algorithm: ['Factorization']
# Log-polar coordinates: []
# Parity (mathematics): []
# Box plot: ['Orientation (geometry)', 'Sense', 'Volume']
# AdS/CFT correspondence: ['Isomorphism']
# Product (mathematics): ['Radical extension', 'Radical symbol', 'Soviet Union', 'Square root']
# List of named matrices: ['System of linear equations', 'Elementary mathematics', 'Matrix multiplication', 'Distance matrix', 'Minor (linear algebra)']
# List of theorems: ['Reflection (mathematics)', 'Polynomial', 'Polynomial ring']
# Self-organizing map: ['Orthogonal matrix', 'Orthonormal basis', 'Congruence (geometry)']
# Oscillator representation: []
# Poisson kernel: ['Orthonormal basis']
# Spectral theory: []
# Antimagic square: ['Magic square']
# Matrix (mathematics): ['Echelon formation', 'Euclidean vector', 'Vector (mathematics and physics)', 'Canonical form', 'Distance matrix']
# Plane stress: ['Orthogonal matrix', 'Orthonormal basis', 'Congruence (geometry)']
# Law of cosines: ['Euler angles', 'Euclidean vector']
# Straight-line grammar: []
# Circumscribed circle: []
# Summation: ['Affine transformation', 'Euler angles', 'Series (mathematics)']
# Orthogonality: []
# Normal operator: []
# Distributive property: ['Split-complex number', 'Additive identity', 'Complex number', 'Mathematics', 'Associative property']
# Minkowski space: ['Null set']
# Intersection: ['Standard basis', 'Line (geometry)']
# Right Sector: []
# Sage (philosophy): ['Computer algebra system']
# Characteristic (algebra): []
# Normed vector space: ['Vector space', 'Euclidean vector', 'Scalar multiplication', 'Vector (mathematics and physics)', 'Additive inverse']
# Three-dimensional space: ['Linear independence']
# Poisson sampling: ['Correlation', 'Mathematics']
# Pattern Blocks: ['Matrix multiplication', 'Multiplication']
# Convex function: ['Fourier series']
# Global optimization: ['Globalization']
# Weighted arithmetic mean: ['Zero matrix']
# Involutory matrix: ['Identity matrix', 'Invertible matrix', 'Singular value']
# Diagonal: ['Row equivalence', 'System of equations', 'Determinant', 'Diagonal matrix', 'Coefficient']
# Direct sum of groups: ['Direct sum']
# Matrix theory (physics): ['Matrix (mathematics)', 'Triangular matrix']
# Hamming code: []
# Ball (mathematics): ['Code', 'Coding theory', 'Gray code', 'Hamming distance']
# Nilpotent: ['Linear equation']
# Area of a circle: ['Cross product', 'Seven-dimensional cross product', 'Coefficient', 'Sign function']
# Data economy: []
# Polar coordinate system: ['Directrix', 'Focus (geometry)']
# Algebraically closed field: []
# Block-stacking problem: ['Linear equation', 'System of linear equations']
# Ideal gas: ['Projective geometry', 'Vanish at infinity']
# Self-similarity: []
# Penrose triangle: ['Projective geometry', 'Vanish at infinity']
# Multiplication algorithm: ['Addition principle']
# Lowest common denominator: []
# Cost function: []
# North Korea: []
# Generalized eigenvector: ['Characteristic polynomial', 'Triangular matrix', 'Weight (representation theory)', 'Multiplicity (mathematics)', 'Multiset']
# PH: []
# Injective function: ['Transformation geometry']
# Alex Sink: ['PageRank', 'ALGOL 58']
# Scalar multiplication: ['Vector notation', 'Matrix (mathematics)', 'Euclidean vector', 'Numerical methods for ordinary differential equations', 'Vector (mathematics and physics)']
# Baden Powell (mathematician): ['Crystal oscillator']
# Alpha Centauri Bb: ['Exponential decay']
# Subset: ['Linear subspace', 'Empty set', 'Set (mathematics)', 'Vector notation', 'Product (mathematics)']
# Orthonormal basis: ['Orthogonality (mathematics)', 'Gram–Schmidt process', 'Orthogonal basis', 'Basis (linear algebra)', 'Vector space']
# Finite field: ['Euclidean algorithm', 'Modulo (mathematics)']
# Nth root: ['Nth root', 'Polynomial', 'Index (economics)']
# Galois theory: ['Code', 'Euclidean algorithm', 'Hamming distance']
# Coefficient: ['Distance matrix', 'System of linear equations', 'Matrix (mathematics)', 'Vector (mathematics and physics)', 'Echelon formation']
# Regression dilution: []
# Operator (mathematics): ['Free module']
# Carl Friedrich Gauss: ['Canonical form', 'Echelon formation', 'Elementary matrix', 'Hermite normal form', 'Matrix decomposition']
# Echelon formation: ['Canonical form', 'Distance matrix', 'Elementary mathematics', 'Matrix (mathematics)', 'Pivot element']
# Dual module: ['Free module']
# Level-set method: ['Partial fraction decomposition', 'Regular expression']
# Conjecture: []
# Transpose: ['Conjugate transpose', 'Matrix (mathematics)', 'Matrix multiplication', 'Symmetric matrix', 'Identity matrix']
# Orbital state vectors: ['State-transition matrix', 'Transition kernel']
# Nilpotent matrix: ['Nilpotent', 'Eigenvalues and eigenvectors']
# Bessel's inequality: []
# Modulo (mathematics): ['Euclidean algorithm']
# Homogeneous differential equation: []
# Vector algebra: ['Euclidean vector', 'Parallelogram law', 'Vector space']
# Logarithm of a matrix: ['Projection (linear algebra)']
# Logarithm: []
# History of mathematics: ['Linear subspace', 'Vector space']
# Haredi Judaism: []
# Altitude (triangle): ['Vector notation']
# Shape: ['Matrix (mathematics)', 'Triangular matrix']
# Force: []
# Monomial: ['Coefficient', 'Degree (graph theory)', 'Leading-order term', 'Order of a polynomial', 'Polynomial']
# General linear group: ['Gaussian elimination', 'System of linear equations']
# Code: ['Modulo (mathematics)']
# Divergence (disambiguation): []
# Parity bit: []
# Graph of a function: ['Y-intercept']
# Google matrix: ['PageRank', 'Eigenvalues and eigenvectors', 'ALGOL 58', 'Alex Sink']
# Division (mathematics): ['Affine transformation', 'Lorentz transformation', 'Gaussian elimination', 'System of linear equations']
# Control variable: []
# Resistor: ['Flow network', 'Condition number']
# 1: ['Canonical form', 'Echelon formation', 'Elementary matrix', 'Hermite normal form', 'Matrix decomposition']
# Consistent and inconsistent equations: ['Least squares', 'Line chart']
# Hadamard matrix: ['Linear equation']
# DFT matrix: ['Laplace expansion', 'Adjugate matrix', 'Matrix (mathematics)']
# Completing the square: ['Quadratic equation', 'Quadratic formula']
# Square root of 2: ['Completing the square', 'Quadratic equation']
# Angle: ['Perpendicular', 'Vector space']
# Smooth maximum: []
# Median: []
# Form factor (electronics): []
# Matrix coefficient: ['Function (mathematics)', 'Triangular matrix', 'Elementary mathematics']
# Linearity: ['Normed vector space', 'Vector space', 'Function (mathematics)', 'Scatter plot']
# Nonlinear control: ['Set-builder notation']
# Population dynamics: ['Recurrence relation']
# Geometry processing: []
# Earthquake engineering: ['Exponential decay', 'Exponential growth']
# Algebraic structure: ['Parallel transport', 'Parallelogram law', 'Unit vector', 'Vector space']
# Orthogonal polynomials: ['Linear algebra', 'Orthogonality (mathematics)', 'Orthonormal basis']
# Quotient space (linear algebra): ['Quotient space (topology)']
# Crystal structure: ['Crystal (mathematics)']
# Noise (signal processing): ['Modulo (mathematics)']
# Closure (mathematics): ['Linear span', 'Linear independence', 'Linear combination', 'Vector space', 'Spanning tree']
# Numerical methods for ordinary differential equations: ['Numerical methods for ordinary differential equations', 'System of linear equations']
# Algebraic expression: ['Matrix multiplication']
# Quadrature (mathematics): []
# Trinomial: ['Coefficient', 'Degree (graph theory)', 'Leading-order term', 'Order of a polynomial', 'Polynomial']
# Partial least squares regression: []
# Complemented subspace: ['Direct sum', 'Concatenation']
# Attractor: []
# Quantity: []
# Truth table: []
# Axiom of countable choice: []
# Inversion (discrete mathematics): ['Sign (mathematics)']
# Discrete-time Markov chain: ['State-transition matrix', 'Transition kernel']
# Multilinear algebra: ['Free module']
# Transformation optics: []
# Order of a polynomial: ['Coefficient', 'Degree (graph theory)', 'Leading-order term', 'Polynomial']
# Adjugate matrix: ['Adjoint', 'Determinant', 'Matrix (mathematics)', 'Laplace expansion', 'Spectral theorem']
# Eugene Seneta: ['Input–output model']
# Diagonalization: ['Diagonal matrix']
# Synthetic division: []
# Confocal conic sections: []
# Normalizing constant: ['Orthonormal basis']
# Bernstein polynomial: []
# De Moivre's theorem: ['Complex number', 'Root of unity']
# Inverse trigonometric functions: ['Associative property', 'Commutative property', 'Matrix multiplication']
# Probability measure: ['Probability theory', 'Sample space']
# Random matrix: ['Dual space', 'Free module', 'Matrix (mathematics)', 'Operator norm']
# Resolution (logic): []
# Long tail: ['Geometric series', 'Euclidean vector', 'Geometric algebra', 'Unit vector', 'Vector (mathematics and physics)']
# Minimal polynomial (linear algebra): ['Eigenvalues and eigenvectors', 'Minimal polynomial (field theory)', 'Diagonal matrix', 'Triangular matrix']
# Resistance distance: ['Flow network', 'Bridge (disambiguation)']
# General algebraic modeling system: ['System of linear equations']
# Method of complements: ['Euclidean vector', 'Matrix (mathematics)', 'Vector (mathematics and physics)']
# Winding number: ['Automorphism', 'Isomorphism']
# Convergent series: ['Eigendecomposition of a matrix', 'Eigenvalues and eigenvectors', 'Euler method']
# Cross-correlation: ['Correlation']
# Cartesian coordinate system: ['Coordinate system', 'Axis', 'Origin (mathematics)', 'Y-intercept', 'Cartesian coordinate system']
# Machine learning: ['Product (mathematics)', 'Radical extension', 'Radical symbol', 'Soviet Union', 'Square root']
# Principal ideal: []
# Spline (mathematics): ['Affine transformation']
# Transfer operator: []
# Plane of rotation: ['Euler angles']
# Polynomial: ['Polynomial', 'Vector space', 'Complex number', 'Linear combination', 'Determinant']
# Linear function (calculus): []
# Galton Laboratory: ['Correlation', 'Mathematics']
# Exponential growth: []
# Point reflection: ['Automorphism', 'Isomorphism']
# Additive identity: ['Split-complex number', 'Complex number', 'Mathematics']
# Totally positive matrix: ['Definite matrix']
# Triangular matrix: ['Matrix (mathematics)', 'Vector space', 'Matrix norm', 'Triangular matrix', 'Polynomial ring']
# Modular arithmetic: ['Euclidean algorithm', 'Modulo (mathematics)']
# Zero-dimensional space: []
# Function composition: ['Isomorphism']
# Root (disambiguation): ['Polynomial', '0', 'Degree of a polynomial', 'Multiplicity (mathematics)', 'Triangular matrix']
# Absolute Infinite: ['Consistency', 'Equation', 'System of linear equations']
# Translation (geometry): ['Orthogonal matrix', 'Orthonormal basis', 'Affine transformation', 'Congruence (geometry)', 'Ellipse']
# Unitary transformation: ['Householder transformation']
# Erlangen program: ['Orthogonal matrix', 'Orthonormal basis', 'Congruence (geometry)']
# Null hypothesis: ['Linear subspace']
# Right-hand rule: ['Cross product', 'Mathematical and theoretical biology']
# Linear interpolation: ['Function (mathematics)']
# Finite field arithmetic: []
# Linear map: ['Isomorphism', 'Affine transformation', 'Linear equation']
# Outcome (probability): ['Addition principle']
# Opposite category: ['Orthogonal matrix', 'Orthonormal basis', 'Orientation character']
# Indeterminate (variable): ['Scalar multiplication', 'Vector (mathematics and physics)', 'Vector space', 'Cancellation property', 'Equality (mathematics)']
# Theory of relativity: ['Vector space']
# Dirichlet eigenvalue: []
# Pseudovector: ['Orbital state vectors', 'State-transition matrix']
# Problem solving: []
# Longship: []
# Polynomial remainder theorem: ['Polynomial', 'Polynomial ring']
# Euclidean algorithm: ['Canonical form', 'Echelon formation', 'Elementary matrix', 'Hermite normal form', 'Matrix decomposition']
# Hooke's law: []
# Matrix multiplication algorithm: ['Matrix multiplication']
# Topological vector space: ['Scalar multiplication', 'Vector space', 'Cancellation property', 'Equality (mathematics)', 'Pointwise product']
# Sobolev inequality: []
# Dependent type: ['Linear independence', 'System of linear equations']
# Stochastic differential equation: ['Numerical methods for ordinary differential equations', 'System of linear equations']
# Correlation coefficient: []
# Divisor: []
# René Descartes: []
# Pythagoras: []
# Antisymmetric tensor: ['Skew-symmetric matrix', 'Transpose']
# Matrix calculus: ['Scalar multiplication', 'Trace (linear algebra)', 'Matrix addition', 'Matrix multiplication', 'Pauli matrices']
# Kronecker delta: ['Outer product']
# Directrix: []
# Unit square: []
# Maxwell's equations: ['System of linear equations']
# Riesz representation theorem: []
# Graph theory: []
# Quadratic: ['Inner product space', 'Quadratic form', 'Root of unity']
# Carrying capacity: ['Exponential growth']
# LINPACK: ['Computer algebra system']
# Hermite normal form: ['Pivot element', 'Canonical form', 'Echelon formation', 'Elementary matrix', 'Matrix decomposition']
# Perpendicular: ['Orthogonality (mathematics)', 'Perpendicular', 'Scalar projection', 'Vector space']
# Focus (geometry): []
# Transverse wave: ['Mathematics']
# Trajectory: []
# Area: ['Volume']
# Volume: ['Parallelepiped', 'Area', 'Orientation (geometry)', 'Sense', 'Size']
# Line segment: ['Conservation law', 'Euclidean vector', 'Geometric algebra', 'Geometric series', 'Vector space']
# Partial correlation: ["Gauss's method", 'Condition number', 'Precision (computer science)']
# Gauss–Bonnet theorem: ['Row equivalence']
# Scientific notation: ['Scientific notation']
# Parallelogram law: ['Euclidean vector', 'Vector space', 'Vector (mathematics and physics)', 'Cauchy–Schwarz inequality', 'Affine transformation']
# Variance swap: ['Correlation']
# Subspace topology: ['Vector space', 'Linear subspace', 'Space (mathematics)']
# Group (mathematics): ['Isometry']
# Sample space: ['Correlation', 'Probability theory']
# Cubic equation: ['Numerical methods for ordinary differential equations', 'System of linear equations']
# Diagonalizable group: ['Diagonal matrix', 'Diagonalizable group', 'Change of basis']
# Hadamard product (matrices): ['Hadamard matrix']
# Prime number: []
# Parametric surface: []
# Constrained optimization: ['Barrier function']
# Derivative: ['Differentiable function', 'Differential equation']
# Morphism: ['Isomorphism', 'Affine transformation']
# Active and passive transformation: ['Change of basis', 'Gröbner basis', 'Transformation (function)']
# Representation theory: ['Basis (linear algebra)', 'Affine transformation', 'Lorentz transformation']
# Map (mathematics): ['Inverse function']
# Vertical tangent: []
# Search engine optimization: []
# Schur's theorem: ['Triangular matrix', 'Characteristic polynomial', 'Orthogonal functions', 'Principal axis theorem', 'Unitary matrix']
# Equivalence class: []
# Parseval's identity: []
# Angle of rotation: []
# Signature (logic): []
# Introduction to the Theory of Error-Correcting Codes: []
# Dynamical system: []
# Market structure: ['Input–output model']
# Greatest common divisor: []
# Combination: []
# Zero of a function: []
# Tridiagonal matrix: ['Transpose']
# Thermal conduction: ['Fourier series']
# Degree of a polynomial: ['Polynomial', 'Polynomial ring', 'Scalar multiplication', 'Vector space', 'Vector (mathematics and physics)']
# Hölder's inequality: ['Dot product', 'Perpendicular']
# Knot (mathematics): ['Local optimum']
# Abstraction (mathematics): ['Abstraction (mathematics)']
# Point (geometry): ['Additive inverse', 'Euclidean vector', 'Scalar multiplication', 'Vector space']
# Five-dimensional space: ['Matrix (mathematics)', 'Triangular matrix', 'Nilpotent']
# Square: ['Invertible matrix', 'Moore–Penrose inverse']
# Matrix similarity: ['Eigenvalues and eigenvectors', 'Characteristic polynomial', 'Eigendecomposition of a matrix', 'Similarity invariance']
# Positive feedback: ['Scatter plot']
# Scheme of work: ['Proper orthogonal decomposition']
# Operator norm: ['Transformation matrix']
# Odd: []
# Origami: ['Coefficient', 'Degree (graph theory)', 'Leading-order term', 'Order of a polynomial', 'Polynomial']
# Linear regression: ['Linear independence', 'Scatter plot']
# Composite number: []
# Power iteration: []
# Hilbert space: []
# Rank (linear algebra): ['Matrix (mathematics)', 'Matrix decomposition', 'Consistency', 'Distance matrix', 'Parameter']
# Trace theory: []
# Curve fitting: []
# Absolute value: ['Complex number', 'Complex conjugate root theorem', 'Differentiable function', 'Differential equation', 'Imaginary unit']
# Independence (mathematical logic): ['Linear independence']
# Automorphism: ['Isomorphism', 'Function composition']
# Flat Earth: ['Euclidean vector']
# Algebraic number theory: []
# Outer product: ['Dot product', 'Cauchy–Schwarz inequality', 'Triangle inequality', 'Norm (mathematics)', 'Matrix (mathematics)']
# Radical symbol: ['Product (mathematics)', 'Radical extension', 'Soviet Union', 'Square root']
# Generalized inverse: ['Inverse function', 'Symmetric matrix', 'Least squares', 'Linear equation']
# Snake lemma: ['Constant-recursive sequence', 'Differentiable function', 'Differential equation']
# Consistency: ['System of linear equations', 'Ω-consistent theory', 'Hyperplane', 'Autonomous system (mathematics)', 'Parameter']
# Square matrix: ['Matrix (mathematics)', 'Identity matrix', 'Abstraction (mathematics)', 'Matrix addition', 'Triangular matrix']
# Unit hyperbola: []
# Hamiltonian matrix: []
# Cauchy matrix: []
# Finitely generated module: ['Free module']
# Gaussian integer: ['Euclidean algorithm', 'Modulo (mathematics)']
# Shift operator: []
# Approximation: []
# Centroid: ['Geometric series', 'Euclidean vector', 'Geometric algebra', 'Unit vector', 'Vector (mathematics and physics)']
# Simplex algorithm: ['Consistency']
# 0: ['Root (disambiguation)', 'Symmetry (geometry)']
# Complex multiplication: ['Complex number', 'Absolute value', 'Complex conjugate']
# Common Core: []
# Affine geometry: []
# Mécanique analytique: ['Cross product', 'Seven-dimensional cross product']
# Turning: ['Automorphism', 'Isomorphism']
# Commutative property: ['Matrix multiplication', 'Matrix addition', 'Pauli matrices', 'Scalar multiplication', 'Associative property']
# Singular submodule: []
# Conductor (class field theory): ['Annihilator (ring theory)']
# Surface area: ['Inverse function']
# Partition function (mathematics): ['Matrix equivalence']
# Geometric calculus: ['Geometric series', 'Euclidean vector', 'Geometric algebra', 'Unit vector', 'Vector (mathematics and physics)']
# Definite matrix: ['Definite matrix', 'Positive definiteness', 'Eigenvalues and eigenvectors']
# Staircase paradox: ['Canonical form', 'Echelon formation', 'Elementary matrix', 'Hermite normal form', 'Matrix decomposition']
# Isotropic quadratic form: []
# Aerodynamics: ['Barrier function', 'Principal component analysis']
# Conformable matrix: ['Matrix multiplication']
# Spacetime triangle diagram technique: []
# Principal axis theorem: ['Canonical form', 'Orthogonal functions', 'Orthogonal matrix']
# Jordan matrix: ['Jordan normal form', 'Canonical form', 'Markov chain']
# Turner syndrome: ['Code']
# Logarithmic derivative: []
# Measure (mathematics): []
# Matrix decomposition: ['Matrix (mathematics)', 'Determinant', 'Elementary matrix', 'Echelon formation', 'Matrix decomposition']
# Terminal velocity: []
# Malthusian growth model: ['Exponential growth']
# Fusion power: []
# Unit cube: ['Parallelepiped']
# Cis (mathematics): ['Complex number', 'Split-complex number']
# Determinantal point process: ['Matrix decomposition', 'Matrix multiplication']
# Category (mathematics): ['Matrix addition', 'Scalar multiplication']
# Normal distribution: ['System of linear equations', 'Substitution (logic)', 'Block-stacking problem', 'Gaussian elimination', 'Linear equation']
# Dual (category theory): ['Operator norm']
# Jordan algebra: []
# Quotient rule: ['History of logarithms']
# Abstract algebra: ['Euclidean algorithm', 'Modulo (mathematics)']
# Fourier series: []
# Cayley–Hamilton theorem: ['Canonical form', 'Minimal polynomial (field theory)', 'Determinant', 'Laplace expansion']
# Differentiation rules: ['Affine transformation', 'Lorentz transformation']
# Arrow's impossibility theorem: ['Orthonormal basis']
# Regular expression: []
# Linear differential equation: ['System of linear equations', 'Vector (mathematics and physics)', 'Distance matrix', 'Vector space', 'Euclidean vector']
# Tablet (pharmacy): []
# H-index: []
# Permutation: ['Parity of a permutation', 'Determinant', 'Permutation']
# C mathematical functions: ['Additive inverse', 'Distributive property', 'Euclidean vector', 'Vector space']
# Monotonic function: ['Local optimum']
# Reverse mathematics: []
# MATLAB: ['Computer algebra system']
# Decomposition (disambiguation): ['Partial fraction decomposition', 'Regular expression']
# Idempotence: []
# Probability theory: ['Principal component analysis', 'Probability', 'Sample space']
# Algebra over a field: ['Addition', 'Matrix multiplication', 'Vector notation', 'Linear subspace']
# Eros (concept): []
# Schrödinger equation: ['Euclidean vector', 'Matrix (mathematics)', 'Vector (mathematics and physics)']
# Analysis of variance: ['Correlation']
# Sphere: ['Barrier function', 'Principal component analysis']
# Operator theory: []
# Sustainable Development Goal 4: []
# Sobolev space: ['Vacuum solution (general relativity)']
# Direction cosine: ['Cross product', 'Seven-dimensional cross product']
# Quadratic function: []
# Parallelogram: ['Parallelepiped', 'Projection (mathematics)']
# Quotient space (topology): []
# Coefficient of variation: ['Bounded variation', 'Mathematics']
# Inverse element: ['Invertible matrix', 'Vector space', 'Mathematics', 'Moore–Penrose inverse', 'Vector (mathematics and physics)']
# SAT: ['Eigenvalue algorithm', 'Eigenvalues and eigenvectors']
# Tuple: ['Matrix (mathematics)', 'Vector space', 'Linear subspace', 'Vector notation', 'Additive identity']
# Identity element: ['Associative property', 'Commutative property', 'Matrix multiplication']
# Trigonometric functions: ['Euler angles']
# Reverse Polish notation: ['Determinant', 'Laplace expansion']
# Expectation value (quantum mechanics): ['Principal component analysis']
# Derivative test: ['Local optimum']
# Reciprocal length: ['Geometric series', 'Euclidean vector', 'Geometric algebra', 'Unit vector', 'Vector (mathematics and physics)']
# Reflection mapping: []
# Cell migration: []
# Eigenvalue algorithm: ['Characteristic polynomial', 'Eigenface', 'Matrix (mathematics)', 'Eigenvalues and eigenvectors', 'Function (mathematics)']
# Unary operation: []
# Numerical analysis: ['Factorization']
# Formula: []
# Pearson correlation coefficient: ['Correlation', 'Mathematics']
# Mersenne prime: []
# Shannon number: ['Code', 'Coding theory', 'Gray code', 'Hamming distance']
# Gray code: ['Code', 'Coding theory', 'Hamming distance']
# Poynting vector: ['Geometric series', 'Unit vector', 'Vector (mathematics and physics)', 'Vector notation', 'Euclidean vector']
# Projection formula: []
# Space (mathematics): ['Vector space', 'Linear subspace', 'System of linear equations', 'Basis (linear algebra)', 'Dimension']
# Knowledge space: ['Product (mathematics)', 'Radical extension', 'Radical symbol', 'Soviet Union', 'Square root']
# Horizontal line test: []
# Comparative advantage: ['Orthogonal functions', 'Triangular matrix', 'Unitary matrix']
# Multivariate statistics: ['Principal component analysis']
# Surjective function: ['Inverse function']
# Radical extension: ['Product (mathematics)', 'Radical symbol', 'Soviet Union', 'Square root']
# Magnus expansion: ['Affine transformation']
# Reflectance: []
# Bounded variation: ['Coefficient of variation', 'Mathematics']
# Index (economics): ['Nth root']
# Symplectic vector space: []
# Volterra operator: []
# Remainder: ['Division algorithm', 'Euclidean algorithm', 'Modulo (mathematics)', 'Quotient']
# Pointwise product: ['Scalar multiplication', 'Vector (mathematics and physics)', 'Vector space', 'Cancellation property', 'Equality (mathematics)']
# Intersection graph: ['Definition', 'Set-builder notation', 'Union (set theory)', 'Venn diagram']
# Invariant theory: ['Inverse function']
# Backslash: ['Linear map']
# Q: []
# Toral subalgebra: []
# Reflection symmetry: []
# Geometric median: ['Color space']
# Sequence: ['Constant-recursive sequence', 'Linear congruential generator', 'Quadrature (mathematics)']
# Deviation (statistics): ['Correlation']
# Graph database: []
# Continuum hypothesis: ['Mathematical induction']
# Invertible matrix: ['Matrix (mathematics)', 'Matrix multiplication', 'Identity matrix', 'Laplace expansion', 'Determinant']
# 2012 in science: []
# Skew-symmetric matrix: ['Determinant', 'Matrix (mathematics)', 'Skew-symmetric graph', 'Skew-symmetric matrix', 'Transpose']
# Characteristic class: ['Characteristic (algebra)']
# Leonard W. Hein: ['Euclidean algorithm', 'Modulo (mathematics)']
# Helmert transformation: []
# One Thousand and One Nights: ['Characteristic polynomial', 'List of unsolved problems in mathematics']
# QR decomposition: []
# Difference of two squares: ['Scalar multiplication', 'Vector space', 'Cancellation property', 'Equality (mathematics)', 'Pointwise product']
# Cross product: ['Determinant', 'Matrix multiplication', 'Cross product', 'Real coordinate space', 'Vector notation']
# Ω-consistent theory: ['System of linear equations', 'Consistency', 'Hyperplane', 'Autonomous system (mathematics)']
# Parameter: ['System of linear equations', 'Variable (mathematics)', 'Consistency', 'Distance matrix', 'Gaussian elimination']
# Support vector machine: ['Geometric series', 'Euclidean vector', 'Geometric algebra', 'Unit vector', 'Dot product']
# Glossary of string theory: []
# Glossary of mathematical symbols: ['Numerical methods for ordinary differential equations', 'Gaussian elimination', 'System of linear equations']
# Unitary operator: []
# Flow diagram: []
# Functional (mathematics): ['Dual space']
# Basic reproduction number: ['Function (mathematics)']
# Edo period: []
# Annual percentage rate: []
# Mean squared error: ['Correlation']
# Riesz space: []
# Apsis: ['Directrix', 'Eccentricity (mathematics)', 'Parabola']
# Module (mathematics): ['Free module', 'Matrix (mathematics)', 'Matrix multiplication', 'Multiplication']
# Mathematical induction: ['Generator (mathematics)', 'Heat equation']
# Origin (mathematics): ['Cartesian coordinate system', 'Coordinate system', 'Axis', 'Y-intercept', 'Ordered pair']
# Multiplication: ['Complex number', 'Matrix multiplication', 'Imaginary unit', 'Interval (mathematics)']
# Finite difference: []
# Cartan–Dieudonné theorem: ['Determinant', 'Adjugate matrix']
# Theorem: ['Determinant']
# Turning Point: []
# Orthogonal instruction set: []
# Canonical basis: []
# Symmetric function: ['Skew-symmetric matrix', 'Transpose']
# Rational number: ['Real number', 'Vector space', 'Scalar multiplication', 'Vector (mathematics and physics)']
# Projection (mathematics): ['Homomorphism', 'Ring homomorphism']
# Transformation (function): ['Affine transformation', 'Lorentz transformation', 'Matrix (mathematics)', 'System of linear equations']
# Perimeter: []
# Definite quadratic form: ['Absolute value']
# Transformational theory: ['Orientation (geometry)', 'Sense', 'Size', 'Volume']
# Venn diagram: ['Definition', 'Set-builder notation', 'Union (set theory)']
# Rank–nullity theorem: []
# Scale factor (computer science): []
# ...
# Chemical equation: []
# Invariant subspace: ['Eigenvalue algorithm', 'Canonical form']
# Complex conjugate representation: ['Complex number', 'Imaginary unit']
# Y-intercept: ['Cartesian coordinate system', 'Coordinate system', 'Axis', 'Origin (mathematics)', 'Ordered pair']
# Fraction: []
# Solution set: ['Linear equation', 'Heat equation', 'Color space']
# Ellipsis: ['Integer sequence', 'Sequence', 'Infinite product', 'Quadratic formula', 'Quadrature (mathematics)']
# Paul Erdős: []
# Null vector: ['Euclidean vector', 'Conservation law', 'Geometric algebra', 'Vector space']
# Line chart: ['Linear equation']
# Automatic differentiation: []
# Relativistic quantum mechanics: []
# Dirac equation: []
# Zero-product property: ['Quadratic equation']
# List of important publications in mathematics: []
# Matrix unit: ['Woodbury matrix identity']
# Anil Nerode: []
# Absorption law: ['Matrix addition', 'Pauli matrices', 'Scalar multiplication']
# Graph (discrete mathematics): ['Geometric series', 'Euclidean vector', 'Geometric algebra', 'Unit vector', 'Vector (mathematics and physics)']
# Integration by substitution: ['Gaussian elimination', 'System of linear equations']
# Orthogonal complement: ['Orthographic projection', 'Orthogonal complement', 'Projection (mathematics)', 'Projection (linear algebra)']
# Real projective plane: ['Projective geometry', 'Homogeneous coordinates', 'Projective plane', 'Vanish at infinity']
# Borel equivalence relation: []
# Zero divisor: []
# Irreducible polynomial: ['Polynomial', 'Polynomial ring']
# Quotient ring: []
# Allan variance: ['Correlation']
# Occupational inequality: []
# Structure (mathematical logic): ['Homomorphism', 'Ring homomorphism']
# Coding theory: ['Code', 'Gray code', 'Hamming distance']
# Rigid body: []
# Factorization: ['Factorization', 'Triangular matrix']
# QR code: ['Color space', 'Geometric median']
# Trigonometric interpolation: []
# Cartesian product: []
# Extrapolation: []
# Quantum information: ['Linear subspace', 'Vector space']
# Event horizon: ['Addition principle']
# Symmetry (geometry): []
# Sequence space: []
# Polynomial interpolation: ['Canonical form', 'Coefficient', "Cramer's rule"]
# Translation: []
# Reduced cost: ['Factorization', 'Triangular matrix']
# Overfitting: ['Least squares', 'Line chart']
# Paradox: ['Linear equation']
# Polar decomposition: ['Linear subspace']
# Linear inequality: ['Consistency']
# Variable (mathematics): ['System of linear equations', 'Parameter', 'Rank (linear algebra)', 'Consistency', 'Random variable']
# Exterior derivative: []
# Irrational number: ['Integer', 'Natural number', 'Rational number', 'Whole number']
# Auxiliary function: ['Eigenvalues and eigenvectors', 'Elementary mathematics', 'Elementary matrix']
# Constant function: ['Polynomial', 'Polynomial ring']
# Kernel (linear algebra): ['Affine transformation', 'Image (mathematics)']
# Smith normal form: []
# Binomial (polynomial): ['Coefficient', 'Degree (graph theory)', 'Leading-order term', 'Order of a polynomial', 'Polynomial']
# Local optimum: []
# Superposition principle: []
# Horizontal convective rolls: []
# Fibonacci cube: ['Recurrence plot']
# Weierstrass factorization theorem: ['Fundamental theorem of algebra']
# Complement: ['Direct sum', 'Concatenation']
# Maple (software): ['Computer algebra system']
# Dimension (vector space): ['Vector space', 'Distance matrix', 'Matrix (mathematics)', 'Linear independence', 'Rank (linear algebra)']
# Power associativity: ['Split-complex number', 'Scalar (mathematics)', 'Additive identity', 'Complex number', 'Mathematics']
# L-semi-inner product: []
# Last Supper: ['Projective geometry', 'Abstraction (mathematics)', 'Vanishing point']
# Harmonic function: []
# Soviet Union: ['Product (mathematics)', 'Radical extension', 'Radical symbol', 'Square root']
# Cholesky decomposition: ['Definite matrix']
# Linear discriminant analysis: ['Consistency']
# Infinite-dimensional vector function: ['Linear independence', 'Linear span']
# Linear code: ['Code', 'Coding theory', 'Gray code', 'Hamming distance']
# Linear group: ['Euclidean vector']
# Adiabatic process: []
# Helmholtz equation: ['Focus (geometry)']
# Rotation formalisms in three dimensions: ['Triangular matrix']
# Pivot element: ['Canonical form', 'Echelon formation', 'Hermite normal form', "Gauss's method", 'Elementary matrix']
# Perfect number: ['Code', 'Coding theory', 'Gray code', 'Hamming distance']
# Normal matrix: ['Diagonalizable group', 'Diagonal matrix']
# Vector notation: ['Vector (mathematics and physics)', 'Unit vector', 'Matrix multiplication', 'Vector space', 'Euclidean vector']
# Einstein notation: ['Series (mathematics)', 'Matrix (mathematics)', 'Matrix addition', 'Pauli matrices', 'Rotation matrix']
# Algebraic number: ['Mathematical and theoretical biology']
# Dilution (equation): ['Crystal (mathematics)', 'Field (mathematics)']
# Orthogonal matrix: ['Determinant', 'Unit vector', "Cramer's rule", 'Invertible matrix', 'Adjugate matrix']
# Laplace's equation: []
# Removable singularity: []
# Linear dynamical system: ['Function (mathematics)', 'Triangular matrix']
# Positive-definite kernel: []
# Composite field (mathematics): ['Matrix multiplication']
# Tower of Hanoi: ['Recurrence relation', 'Consistency', 'Equation', 'System of linear equations']
# Isomorphism: ['Linear map', 'Linear equation']
# Seven-dimensional cross product: []
# LC circuit: ['Flow network', 'Condition number']
# Graph isomorphism problem: ['Definable', 'Direct sum', 'Direct sum of groups']
# Iteration: []
# Direct sum of modules: ['Direct sum', 'Concatenation']
# Hypotenuse: []
# Coordinate vector: ['Matrix multiplication', 'Basis (linear algebra)', 'Geometric algebra', 'Geometric series', 'Conservation law']
# Included angle: []
# Leibniz formula for determinants: ['Determinant']
# History of mathematical notation: []
# Permutation matrix: ['Elementary matrix', 'Matrix multiplication', 'Identity matrix', 'QR algorithm', 'Gaussian elimination']
# Sign (mathematics): ['Matrix (mathematics)', 'Matrix addition', 'Pauli matrices', 'Rotation matrix', 'Triangular matrix']
# Homogeneous space: ['Numerical methods for ordinary differential equations']
# Laplace distribution: ['Determinant', 'Laplace expansion']
# Integral: ['Affine transformation', 'Lorentz transformation']
# Computer algebra system: []
# Locally nilpotent derivation: ['Annihilator (ring theory)', 'Conductor (class field theory)']
# Parity-check matrix: ['Code', 'Coding theory', 'Gray code', 'Hamming distance']
# Descartes' theorem: ['Split-complex number']
# Weight (representation theory): ['Characteristic polynomial', 'Multiplicity (mathematics)', 'Multiset', 'Generalized eigenvector']
# Flow (mathematics): ['Affine transformation', 'Lorentz transformation']
# Bridge (disambiguation): ['Flow network']
# Incomplete LU factorization: ['Factorization']
# Ellipse: ['Circle']
# Continuous function: ['Inner product space']
# Nullity theorem: []
# Codomain: []
# Parent function: []
# Projection-slice theorem: []
# Formal language: ["Gauss's method", 'Data analysis', 'Precision (computer science)']
# Fredholm determinant: []
# Probability vector: ['Markov chain']
# Indigenous education: ['Determinant', 'Laplace expansion']
# Field trace: ['Matrix norm']
# Conjugate transpose: ['Transpose', 'Matrix (mathematics)', 'Matrix multiplication', 'Square root of a matrix', 'Complex number']
# Low basis theorem: []
# Multiplicative inverse: ['Generalized inverse', 'Absolute value', 'Complex conjugate', 'Complex number', 'Complex plane']
# Unit vector: ['Vector notation', 'Vector (mathematics and physics)', 'Vector space', 'Matrix multiplication', 'Real coordinate space']
# Vertex (graph theory): ['Focus (geometry)', 'Ellipse', 'Matrix multiplication', 'Pattern Blocks', 'Vertex (graph theory)']
# Sparse matrix: ["Horner's method", 'Mathematics', 'Matrix norm']
# Rotation matrix: ['Matrix (mathematics)', 'Identity matrix', 'Matrix norm', 'Triangular matrix', 'Matrix multiplication']
# Nearest neighbor search: ['Code', 'Coding theory', 'Gray code', 'Hamming distance']
# Sense: ['Orientation (geometry)', 'Size', 'Volume']
# Quadratic form: ['Matrix multiplication', 'System of linear equations', 'Inner product space']
# Linear subspace: ['Linear subspace', 'Vector notation', 'Space (mathematics)', 'Basis (linear algebra)', 'Proper map']
# Laplace operator: ['Affine transformation', 'Lorentz transformation', 'Square root of a matrix']
# Property (mathematics): ['Affine transformation', 'Lorentz transformation']
# Guitar tunings: ['Jordan matrix', 'Jordan normal form', 'Markov chain']
# Saddle point: []
# Scalar projection: ['Perpendicular']
# Cryptography: ['Modulo (mathematics)']
# Block matrix: ['Matrix multiplication', 'Multiplication', 'Pattern Blocks', 'Euclidean vector', 'Matrix (mathematics)']
# Composition operator: []
# Rational root theorem: ['Polynomial ring', 'Rational root theorem']
# Four color theorem: []
# Icosahedral symmetry: ['Norm (mathematics)']
# Vibration: ['Barrier function', 'Principal component analysis']
# Approximation theory: []
# Reaction (physics): []
# Change of basis: ['Basis (linear algebra)', 'Matrix multiplication', 'Eigenvalues and eigenvectors', 'Change of basis', 'Gröbner basis']
# Triviality (mathematics): ['Vector space', 'Numerical methods for ordinary differential equations', 'Linear combination', 'System of linear equations']
# Function (mathematics): ['Linear subspace', 'Vector space', 'Inverse function', 'System of linear equations', 'Sign function']
# Multiplication sign: ['Hadamard matrix', 'Matrix multiplication', 'Vector notation']
# Least squares: ['Generalized inverse', 'Linear equation', 'Gaussian elimination']
# Dimensional analysis: []
# Forcing (mathematics): []
# Symmetric matrix: ['Transpose', 'Generalized inverse', 'System of linear equations', 'Matrix (mathematics)', 'Linear combination']
# Standard error: []
# Vector calculus identities: ['Parallelogram law']
# Interval (mathematics): ['Scalar multiplication', 'Vector notation', 'Vector (mathematics and physics)', 'Vector space', 'Addition']
# Matrix equivalence: ['Change of basis', 'Linear equation', 'Similarity (geometry)']
# Pendulum: ["Gauss's method", 'Condition number', 'Precision (computer science)']
# Numerical integration: ['Affine transformation', 'Lorentz transformation']
# Interior product: ['Exterior algebra']
# Hamming weight: ['Code', 'Coding theory', 'Gray code', 'Hamming distance']
# Homogeneous polynomial: ['Vector space', 'Scalar multiplication', 'Equality (mathematics)', 'Normed vector space', 'Pointwise product']
# Involution (mathematics): ['Gaussian elimination', 'System of linear equations']
# Google: ['PageRank', 'ALGOL 58', 'Alex Sink']
# Green's identities: []
# Cancellation property: []
# Covariance: ['Principal component analysis']
# Inverse problem: ['Inverse problem', 'Mathematics', 'Bounded variation', 'Invertible matrix', 'Moore–Penrose inverse']
# Lagrange's theorem (group theory): ['Cross product', 'Seven-dimensional cross product']
# Perron–Frobenius theorem: ['Stochastic matrix']
# Spanning tree: ['Linear combination', 'Linear subspace', 'Closure (mathematics)', 'Generator (mathematics)']
# Hermitian matrix: ['Matrix (mathematics)', 'Orthogonal functions']
# Group action: ['Affine transformation', 'Lorentz transformation']
# Probability: ['State-transition matrix', 'Transition kernel', 'Probability theory', 'Sample space']
# Electric generator: []
# Homomorphism: ['Homomorphism', 'Linear map', 'Ring homomorphism']
# Proper map: ['Linear subspace', 'Vector space', 'Empty set', 'Set (mathematics)', 'Subset']
# Precalculus: ['Determinant', 'Laplace expansion']
# Mean: ['Correlation']
# Order of magnitude: ['Exponential decay']
# Covariance matrix: ['Principal component analysis']
# Kernel (image processing): ['Null set', 'Differentiable function']
# Desargues's theorem: ['Projective geometry', 'Vanish at infinity']
# Multilinear map: []
# Eigenvector centrality: ['Eigenvalues and eigenvectors', 'Eigenface', 'Function (mathematics)', 'Triangular matrix']
# Characteristic equation (calculus): ['Multiplicity (mathematics)', 'Characteristic polynomial', 'Multiset']
# Orthogonality principle: []
# Axis: ['Cartesian coordinate system', 'Coordinate system', 'Origin (mathematics)', 'Y-intercept', 'Ordered pair']
# Hyperbola: ['Mathematics']
# De Moivre's formula: ['Root of unity']
# Lagrange's identity: ['Cross product', 'Seven-dimensional cross product']
# Formal power series: []
# Finite set: ['Euclidean algorithm', 'Modulo (mathematics)']
# Ring homomorphism: ['Homomorphism']
# Euler's identity: ['Complex number']
# Integer sequence: ['Quadrature (mathematics)', 'Sequence']
# Sigma: ['Series (mathematics)', 'Summation']
# Participation criterion: ['Paradox', 'Crystal (mathematics)']
# Transformation geometry: ['Automorphism', 'Isomorphism']
# Norm (mathematics): ['Inner product space', 'Outer product', 'Euclidean vector', 'Conjugate prior', 'Frobenius inner product']
# Singularity (mathematics): ['Invertible knot', 'Skew-symmetric matrix']
# Equation solving: ['Set-builder notation']
# Jacobian matrix and determinant: ['Determinant']
# Crank–Nicolson method: ['Gaussian elimination', 'System of linear equations', 'Substitution (logic)', 'Linear equation']
# Hofstadter sequence: ['Recurrence plot']
# Quadratic equation: ['Barrier function', 'Solution set']
# Binary relation: ['Vector space']
# Linear fractional transformation: ['Affine transformation', 'Lorentz transformation', 'Change of basis', 'Gröbner basis', 'Transformation (function)']
# Parallel transport: ['Parallelogram law', 'Vector space']
# Voltage: ['Flow network', 'Condition number']
# Integer factorization: []
# Geometric algebra: ['Geometric series', 'Euclidean vector', 'Unit vector', 'Vector (mathematics and physics)']
# Ring (mathematics): ['Union (set theory)', 'Empty set', 'Definition', 'Set-builder notation', 'Venn diagram']
# Identity function: ['Inverse function']
# Uncorrelatedness (probability theory): ['Principal component analysis']
# String (computer science): ['Nilpotent', 'Nilpotent matrix']
# Scalar curvature: ['Numerical methods for ordinary differential equations', 'System of linear equations']
# Cubic function: ['Inverse function']
# Lorentz transformation: ['Affine transformation', 'Transformation (function)', 'Geometric transformation']
# Bilinear form: ['Free module', 'Barrier function']
# Projective geometry: ['Linear equation']
# Equals sign: ['Cross product', 'Seven-dimensional cross product']
# Logistic function: ['Exponential decay', 'Exponential growth']
# Principal ideal domain: []
# Ramp function: []
# Coset: ['Exterior algebra', 'Interior product', 'Code']
# Row and column spaces: ['Rank (linear algebra)', 'Dual space', 'Matrix norm', 'Vector space', 'Matrix (mathematics)']
# Quasi-arithmetic mean: []
# Union (set theory): ['Empty set', 'Ring (mathematics)', 'Intersection (set theory)', 'Set (mathematics)', 'Subset']
# System of equations: []
# Dieudonné determinant: ['Triangular matrix']
# Hat operator: ['Mathematical proof', 'Triangular matrix']
# Serre's multiplicity conjectures: []
# Transfinite induction: []
# Argument: ['Complex number', 'Complex plane']
# Orthogonal coordinates: ['Orthogonal matrix', 'Unit vector', 'Principal axis theorem']
# Addition: ['System of linear equations', 'Algebra over a field', 'Matrix multiplication', 'Vector notation', 'Linear subspace']
# Taylor's theorem: []
# Gauss's method: ['System of linear equations', 'Block-stacking problem', 'Gaussian elimination', 'Linear equation']
# Symmetry: ['Skew-symmetric matrix', 'Transpose']
# Shuffling: []
# Z-matrix (mathematics): ['Matrix (mathematics)', 'Triangular matrix']
# Well-order: []
# Laplacian matrix: []
# Determinant: ['System of linear equations', 'Linear equation', 'Permutation', 'Determinant', 'Distance matrix']
# Triangulation (surveying): []
# Reciprocal gamma function: []
# Transformation semigroup: []
# Arithmetic mean: ['Series (mathematics)', 'Summation']
# Diamond: ['Crystal (mathematics)']
# Shot grouping: ['Greatest common divisor']
# Elimination theory: ['Parametric surface']
# Partition of a set: ['Matrix multiplication', 'Multiplication', 'Pattern Blocks', 'Row equivalence']
# Adjacency matrix: ['Matrix (mathematics)', 'Dual space', 'Matrix multiplication', 'Pattern Blocks', 'Elementary matrix']

# %%
df_concepts.to_json("../dat/textbooks/de2.json")

# %% [markdown]
# This experiment deals with the co-occurence of concepts on the same page or surrounding pages. It is based on the assumption that dependencies are used within close proximity.
# Pseudo-algorithm:
# 1. For each concept: Find all other concepts that are 1. introduced before but 2. mentioned again within proximity of the introduction of the concept (1-2 page padding).

# %%
import os
import pandas as pd
import numpy as np

# %%
# load all book indices into storage and create a set of wikipedia concepts
path = "../dat/index_by_wiki/"
wiki_concepts = {}

def get_page_list(page_string):
    if not isinstance(page_string, float) and "nan" in page_string: return None
    pages_int = [int(page_string)] if isinstance(page_string, float) else list(map(int, page_string.split(",")))
    return pages_int

for book in os.listdir(path):
    index = pd.read_csv(path + book).dropna()
    index['pages'] = index.pages.apply(get_page_list)
    index = index.dropna()
    index['first_page'] = index.pages.apply(min) # add first page of index entry
    index['num_pages'] = index.pages.apply(len)
    print(book)
    #print(index.num_pages.mean())

    def dep_condition(first_page, x):
        diffs = first_page-np.array(x)
        return np.any((diffs<=5) & (diffs>=1))

    def get_deps(first_page):
        filter = ((index.first_page < first_page) & # introduced before
                 (index.pages.apply(lambda x: dep_condition(first_page, x)))) # mentioned again in the introduction of the concept
        return list(index.wiki_concept[filter])

    index['deps'] = index.first_page.apply(get_deps)
    has_deps = index.deps.apply(len) > 0

    print(np.sum(has_deps))
    for concept, deps in zip(index.wiki_concept[has_deps], index.deps[has_deps]):
        if concept not in wiki_concepts: wiki_concepts[concept] = []
        wiki_concepts[concept] += deps
# Out:
# Kuttler-LinearAlgebra-AFirstCourse-2017A.csv
# 141
# Beezer_First_Course.csv
# 51
# textbook_Hoffman_Kunze.csv
# 230
# Nicholson-OpenLAWA-2019A.csv
# 679
# Linear algebra done right — Axler.csv
# 134
# Math1410_print.csv
# 133
# Hefferon_LinAlgebra.csv
# 308
# linear-Cherey, Denton.csv
# 100
# interactive_textbook.csv
# 153
# CollegeAlgCoreq-WEB.csv
# 251

# %%
for conc, deps in wiki_concepts.items():
    twice_deps = set([x for x in deps if deps.count(x) >= 2])
    if len(twice_deps):
        print(conc + ": " + ", ".join(twice_deps))
# Out:
# Absolute value: Complex conjugate, Complex number
# Basic feasible solution: System of linear equations, Gaussian elimination, Triviality (mathematics)
# Basis: Linear span, Row and column spaces, Linear independence
# Basis (linear algebra): Linear span, Row and column spaces, Basis
# Cauchy–Schwarz inequality: Dot product, Degenerate bilinear form, Inner product space, Norm, Euclidean vector
# Change of basis: Eigenvalues and eigenvectors, Basis (linear algebra), Invertible matrix, Transformation matrix
# Cholesky decomposition: Definite matrix, Positive definiteness, Routh–Hurwitz stability criterion
# Coefficient: System of linear equations
# Complex conjugate: Fundamental theorem of algebra, Complex number
# Complex number: Homography
# Complex plane: Fundamental theorem of algebra, Complex conjugate, Complex number, Imaginary number
# Cramer's rule: Triangular matrix, Adjugate matrix, Cofactor, Minor (linear algebra), Invertible matrix, Determinant
# ...
